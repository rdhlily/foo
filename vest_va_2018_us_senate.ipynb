# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import maup
from zipfile import ZipFile
import numpy as np
import os
import shutil

# %% [markdown]
# # US Senate

# %%
#Read in election results
#unzip all county shapefiles
#read in all county shapefiles
#concatenate all files (same fields should keep it simple) - use a dictionary?

# %%
cd ../
# Out:
# /Users/lilyfalk/sandbox/pdv-va

# %% [markdown]
# ### Final File - Load

# %%
#Check out final file: https://dataverse.harvard.edu/file.xhtml?persistentId=doi:10.7910/DVN/UBKYRU/FQDLOO&version=33.0 
final = gpd.read_file('./vest_va/va_2018_senate/va_2018_senate.shp')

# %%
final.head() #	G18USSOWRI = "Write-in Votes" from vest documentation
# Out:
#   COUNTYFP         LOCALITY   VTDST        PRECINCT  G18USSDKAI  G18USSRSTE  \
# 0      001  Accomack County  000101    Chincoteague         556         994
# 1      001  Accomack County  000201        Atlantic         182         459
# 2      001  Accomack County  000202  Greenbackville         316         577
# 3      001  Accomack County  000301      New Church         588         477
# 4      001  Accomack County  000401          Bloxom         121         277
#
#    G18USSLWAT  G18USSOWRI                                           geometry
# 0          17           0  POLYGON Z ((-75.42507 37.89957 0.00000, -75.42...
# 1          11           0  POLYGON Z ((-75.59978 37.87664 0.00000, -75.59...
# 2           8           1  POLYGON Z ((-75.49919 37.93416 0.00000, -75.49...
# 3          11           0  POLYGON Z ((-75.64987 37.92702 0.00000, -75.64...
# 4           4           0  POLYGON Z ((-75.71556 37.87513 0.00000, -75.71...

# %% [markdown]
# # Election Results: US Senate

# %%
#US senate results from the state: https://historical.elections.virginia.gov/elections/view/134055/ 
df = pd.read_csv('./vest_va/Virginia_Elections_Database__2018_U_S_Senate_General_Election_including_precincts.csv')

# %% [markdown]
# - Election race/Candidate name format change to match VEST
# - precinct identifier change to match

# %%
df.head() #Ward not appearing, should it?
# Out:
#        County/City Ward                   Pct Timothy Michael Kaine  \
# 0              NaN  NaN                   NaN            Democratic
# 1  Accomack County    -    101 - Chincoteague                   487
# 2  Accomack County    -        201 - Atlantic                   159
# 3  Accomack County    -  202 - Greenbackville                   277
# 4  Accomack County    -      301 - New Church                   515
#
#   Corey Alan Stewart Matthew Joseph Waters All Others Total Votes Cast
# 0         Republican           Libertarian        NaN              NaN
# 1                932                    16          0            1,435
# 2                430                    10          0              599
# 3                541                     7          1              826
# 4                447                    10          0              972

# %%
df['County/City'].value_counts()
# Out:
# Fairfax County           250
# Virginia Beach City      102
# Prince William County    102
# Loudoun County           100
# Henrico County            94
#                         ...
# Williamsburg City          4
# Buena Vista City           3
# Lexington City             3
# Norton City                2
# TOTALS                     1
# Name: County/City, Length: 134, dtype: int64

# %%
final['LOCALITY'].value_counts() # makes sense that these are slightly fewer based on merges from documentation
# Out:
# Fairfax County           245
# Virginia Beach City      100
# Loudoun County            98
# Prince William County     96
# Henrico County            90
#                         ...
# Falls Church City          3
# Buena Vista City           2
# Williamsburg City          2
# Lexington City             1
# Norton City                1
# Name: LOCALITY, Length: 133, dtype: int64

# %% [markdown]
# ## Figure out overlap and rename accordingly to match final file

# %% [markdown]
# **From shp**, want columns: ['COUNTYFP', 'VTDST', 'geometry']
#
# **From df**, want columns: ['Count/City'] adapted to match ['LOCALITY'], ['Pct'] adapted to ['PRECINCT'], all election/candidate/race formats match final

# %%
set(df['County/City']) - set(final['LOCALITY']) #account for totals later
# Out:
# {'TOTALS', nan}

# %%
df['Pct'].value_counts()
# Out:
# Provisional                       116
# Ab - Central Absentee Precinct    108
# 101 - Precinct 1-1                  9
# 201 - Precinct 2-1                  9
# 301 - Precinct 3-1                  9
#                                  ...
# 201 - Columbia                      1
# 30 - South Norfolk (CD 3)           1
# 711 - Price (CD 11)                 1
# 401 - Number Four                   1
# 201 - Jamestown A (CD 2)            1
# Name: Pct, Length: 2434, dtype: int64

# %%
final['PRECINCT'].value_counts()
# Out:
# Courthouse      12
# Precinct 3-1     9
# Precinct 1-1     9
# Precinct 2-1     9
# Precinct 4-1     8
#                 ..
# Forestdale       1
# Lynbrook         1
# HUNTERSVILLE     1
# Precinct 3       1
# CLINCHBURG       1
# Name: PRECINCT, Length: 2252, dtype: int64

# %%
final.head()
# Out:
#   COUNTYFP         LOCALITY   VTDST        PRECINCT  G18USSDKAI  G18USSRSTE  \
# 0      001  Accomack County  000101    Chincoteague         556         994
# 1      001  Accomack County  000201        Atlantic         182         459
# 2      001  Accomack County  000202  Greenbackville         316         577
# 3      001  Accomack County  000301      New Church         588         477
# 4      001  Accomack County  000401          Bloxom         121         277
#
#    G18USSLWAT  G18USSOWRI                                           geometry
# 0          17           0  POLYGON Z ((-75.42507 37.89957 0.00000, -75.42...
# 1          11           0  POLYGON Z ((-75.59978 37.87664 0.00000, -75.59...
# 2           8           1  POLYGON Z ((-75.49919 37.93416 0.00000, -75.49...
# 3          11           0  POLYGON Z ((-75.64987 37.92702 0.00000, -75.64...
# 4           4           0  POLYGON Z ((-75.71556 37.87513 0.00000, -75.71...

# %% [markdown]
# RENAME COLUMNS BUT NO CONTENT CHANGE

# %%
df['LOCALITY'] = df['County/City']
df['G18USSDKAI'] = df['Timothy Michael Kaine']
df['G18USSRSTE'] = df['Corey Alan Stewart']
df['G18USSLWAT'] = df['Matthew Joseph Waters']
df['G18USSOWRI'] = df['All Others']
df.head()
# Out:
#        County/City Ward                   Pct Timothy Michael Kaine  \
# 0              NaN  NaN                   NaN            Democratic
# 1  Accomack County    -    101 - Chincoteague                   487
# 2  Accomack County    -        201 - Atlantic                   159
# 3  Accomack County    -  202 - Greenbackville                   277
# 4  Accomack County    -      301 - New Church                   515
#
#   Corey Alan Stewart Matthew Joseph Waters All Others Total Votes Cast  \
# 0         Republican           Libertarian        NaN              NaN
# 1                932                    16          0            1,435
# 2                430                    10          0              599
# 3                541                     7          1              826
# 4                447                    10          0              972
#
#           LOCALITY  G18USSDKAI  G18USSRSTE   G18USSLWAT G18USSOWRI
# 0              NaN  Democratic  Republican  Libertarian        NaN
# 1  Accomack County         487         932           16          0
# 2  Accomack County         159         430           10          0
# 3  Accomack County         277         541            7          1
# 4  Accomack County         515         447           10          0

# %%
#Remove first row of df with dem rep etc - only do once!
df = df.iloc[1:]

# %%
df = df.drop(['County/City', 'Ward', 'Timothy Michael Kaine', 'Corey Alan Stewart', 'Matthew Joseph Waters', 'All Others', 'Total Votes Cast'], axis = 1)

# %%
len(set(df['Pct'].str.slice(start = 6)) - set(final['PRECINCT'])) #so precinct column manipulation still needs work ...
# Out:
# 1494

# %% [markdown]
# Maybe make unique identifier using vtsd and county?

# %%
(final['LOCALITY'] + final['VTDST'].str.slice(start = 3)).nunique()
# Out:
# 2441

# %%
final['VTDST'].nunique()
final['VTDST'].str.slice(stop = 3).value_counts()
# Out:
# 000    2408
# 027      17
# 005      12
# 029      10
# 135       9
# 017       7
# Name: VTDST, dtype: int64

# %% [markdown]
# So, while the first three digits of `VTDST` are not always 0, locality combined with the last three of that code still has the same number of unique values.

# %%
len(set(final['VTDST'].str.slice(start = 3)) - set(df['Pct'].str.slice(stop = 3)))
# Out:
# 102

# %%
df['Pct'].str.slice(stop = 4).value_counts()
# Out:
# Prov    149
# Ab -    136
# 101     102
# 201     102
# 301      95
#        ...
# 914       1
# 733       1
# 933       1
# 519       1
# 122       1
# Name: Pct, Length: 392, dtype: int64

# %% [markdown]
# ## Look into merges
#
# Peter noted that these were likely geometry changes that we will not worry about. Instead, need to focus on re-allocating votes.

# %%
# 'Albemarle: Add Mechums River to match county GIS shapefile'
df[df['LOCALITY'].map(lambda x: 'Albemarle' in str(x)) & df['Pct'].map(lambda x: 'Mechums' in str(x))]
# Out:
#                     Pct          LOCALITY G18USSDKAI G18USSRSTE G18USSLWAT  \
# 48  606 - Mechums River  Albemarle County      1,426        695         61
#
#    G18USSOWRI
# 48          4

# %%
# 'Arlington: Adjust Gunston/Oakridge to match county GIS shapefile'
df[(df['LOCALITY'].map(lambda x: 'Arlington' in str(x)) & df['Pct'].map(lambda x: 'Gunston' in str(x)))]
# Out:
#               Pct          LOCALITY G18USSDKAI G18USSRSTE G18USSLWAT  \
# 177  52 - Gunston  Arlington County      1,092        193         41
#
#     G18USSOWRI
# 177          8

# %%
final[(final['LOCALITY'].map(lambda x: 'Arlington' in str(x)) & final['PRECINCT'].map(lambda x: 'Gunston' in str(x)))]
# Out:
#      COUNTYFP          LOCALITY   VTDST PRECINCT  G18USSDKAI  G18USSRSTE  \
# 2418      013  Arlington County  000052  Gunston        1375         224
#
#       G18USSLWAT  G18USSOWRI  \
# 2418          47           9
#
#                                                geometry
# 2418  POLYGON Z ((-77.08225 38.84343 0.00000, -77.08...

# %%
df[(df['LOCALITY'].map(lambda x: 'Arlington' in str(x)) & df['Pct'].map(lambda x: 'Oakridge' in str(x)))]
# Out:
#                Pct          LOCALITY G18USSDKAI G18USSRSTE G18USSLWAT  \
# 157  32 - Oakridge  Arlington County        577        179         21
#
#     G18USSOWRI
# 157          4

# %%
final[(final['LOCALITY'].map(lambda x: 'Arlington' in str(x)) & final['PRECINCT'].map(lambda x: 'Oakridge' in str(x)))]
# Out:
#      COUNTYFP          LOCALITY   VTDST  PRECINCT  G18USSDKAI  G18USSRSTE  \
# 2419      013  Arlington County  000032  Oakridge         727         208
#
#       G18USSLWAT  G18USSOWRI  \
# 2419          24           5
#
#                                                geometry
# 2419  POLYGON Z ((-77.07478 38.85172 0.00000, -77.07...

# %%
(final['LOCALITY'] + final['VTDST']).nunique()
# Out:
# 2441

# %%
final['LOCALITY'].nunique()
# Out:
# 133

# %%
county_dict = pd.Series(final['COUNTYFP'].values, index = final['LOCALITY']).to_dict()

# %%
df['COUNTYFP'] = df['LOCALITY'].map(county_dict)

# %%
(df['COUNTYFP'] + df['Pct']).nunique()
# Out:
# 2754

# %%
(df['LOCALITY'] + df['Pct'].str.slice(stop = 3)).nunique()
# Out:
# 2704

# %%
final.shape
# Out:
# (2463, 9)

# %%
final[final['LOCALITY'] == 'Accomack County']['G18USSDKAI']
sum(final[final['LOCALITY']=='Accomack County']['G18USSDKAI'].map(lambda x: int(x))) - sum(df[df['LOCALITY']=='Accomack County']['G18USSDKAI'].map(lambda x: int(x)))
# Out:
# 0

# %%
#Probably assigning votes at county level not precinct
len(final[final['LOCALITY']=='Accomack County']['G18USSDKAI'].map(lambda x: int(x))) - len(df[df['LOCALITY']=='Accomack County']['G18USSDKAI'].map(lambda x: int(x)))
# Out:
# -2

# %%
final[final['LOCALITY']=='Accomack County']['PRECINCT']
# Out:
# 0       Chincoteague
# 1           Atlantic
# 2     Greenbackville
# 3         New Church
# 4             Bloxom
# 5           Parksley
# 6              Saxis
# 7         Mappsville
# 8                Rue
# 9            Accomac
# 10           Tangier
# 11            Nandua
# 12           Bobtown
# 13             Melfa
# 14      Wachapreague
# 15           Painter
# Name: PRECINCT, dtype: object

# %%
df[df['LOCALITY']=='Accomack County']['Pct']
# Out:
# 1                 101 - Chincoteague
# 2                     201 - Atlantic
# 3               202 - Greenbackville
# 4                   301 - New Church
# 5                       401 - Bloxom
# 6                     402 - Parksley
# 7                        403 - Saxis
# 8                   501 - Mappsville
# 9                          502 - Rue
# 10                     601 - Accomac
# 11                     602 - Tangier
# 12                      701 - Nandua
# 13                     801 - Bobtown
# 14                       802 - Melfa
# 15                803 - Wachapreague
# 16                     901 - Painter
# 17    Ab - Central Absentee Precinct
# 18                       Provisional
# Name: Pct, dtype: object

# %%
df[(df['LOCALITY'].map(lambda x: 'Arlington' in str(x)) & df['Pct'].map(lambda x: 'Provisional' in str(x)))]
# Out:
#              Pct          LOCALITY G18USSDKAI G18USSRSTE G18USSLWAT  \
# 181  Provisional  Arlington County         96         27          5
#
#     G18USSOWRI COUNTYFP
# 181          1      013

# %%
df[(df['LOCALITY'].map(lambda x: 'Arlington' in str(x)) & df['Pct'].map(lambda x: 'Absentee' in str(x)))]
# Out:
#                                 Pct          LOCALITY G18USSDKAI G18USSRSTE  \
# 180  Ab - Central Absentee Precinct  Arlington County     17,893      2,307
#
#     G18USSLWAT G18USSOWRI COUNTYFP
# 180        335         54      013

# %%
group_test = df.groupby(['COUNTYFP']).sum()
group_test
# Out:
#                                                         Pct  \
# COUNTYFP
# 001       101 - Chincoteague201 - Atlantic202 - Greenbac...
# 003       101 - Woodbrook103 - Branchlands104 - Agnor-hu...
# 005       101 - Arritt103 - Dameron201 - Humpback Bridge...
# 007       101 - Number One201 - Number Two301 - Number T...
# 009       101 - Wright Shop102 - New Glasgow103 - Coolwe...
# ...                                                     ...
# 800       101 - Belleharbour (CD 3)102 - Driver (CD 3)10...
# 810       1 - North Beach2 - South Beach3 - Ocean Lakes4...
# 820       1 - Ward A2 - Ward B3 - Ward C4 - Ward DAb - C...
# 830       1 - Stryker2 - MatoakaAb - Central Absentee Pr...
# 840       101 - Merrimans102 - Old Town201 - Virginia Av...
#
#                                                    LOCALITY  \
# COUNTYFP
# 001       Accomack CountyAccomack CountyAccomack CountyA...
# 003       Albemarle CountyAlbemarle CountyAlbemarle Coun...
# 005       Alleghany CountyAlleghany CountyAlleghany Coun...
# 007       Amelia CountyAmelia CountyAmelia CountyAmelia ...
# 009       Amherst CountyAmherst CountyAmherst CountyAmhe...
# ...                                                     ...
# 800       Suffolk CitySuffolk CitySuffolk CitySuffolk Ci...
# 810       Virginia Beach CityVirginia Beach CityVirginia...
# 820       Waynesboro CityWaynesboro CityWaynesboro CityW...
# 830       Williamsburg CityWilliamsburg CityWilliamsburg...
# 840       Winchester CityWinchester CityWinchester CityW...
#
#                                                  G18USSDKAI  \
# COUNTYFP
# 001       4871592775151062363929931243630755214358155869...
# 003       1,2685361,1151,6411,3671,4901,9331,3561,8111,2...
# 005                    136509011755159125143971633773041360
# 007                                     2924112862914731823
# 009                   4693711296911822064581176221447983504
# ...                                                     ...
# 800       8209698894434901,1479043145817661,021443375273...
# 810       1,0109195827961,0009005701,0247387421,1539881,...
# 820                                    5641,0167981,1922790
# 830                                          2,1001,9544715
# 840                                1,0287549278684366815417
#
#                                                  G18USSRSTE  \
# COUNTYFP
# 001       9324305414472603631171809849517176331130828549...
# 003       5911703434937987183082897736412084513441784914...
# 005                3321262232722223552423251254313842401560
# 007                                     6057117587127422905
# 009             3256753949574594891,2422761,1742981,0953923
# ...                                                     ...
# 800       2531,36867477667749036713113925477242404686275...
# 810       1,2257776219485719996458339521,202934611931828...
# 820                                      4739826991,3202372
# 830                                              7386101990
# 840                                  7375774525903296792930
#
#                                                  G18USSLWAT  \
# COUNTYFP
# 001                              16107104704011219381014100
# 003       5320305160477756523217311910201541384410233627...
# 005                                         432636310598610
# 007                                             71522161740
# 009                                   620133041124937940120
# ...                                                     ...
# 800       1747311617261554127714870232126317265062151621...
# 810       5052275539492051404458455137335448512122323235...
# 820                                              2235305660
# 830                                                  565800
# 840                                         344336351131200
#
#                                                  G18USSOWRI
# COUNTYFP
# 001                                      001000011003100010
# 003                       411138636122110185200115220454130
# 005                                          00000000000110
# 007                                                 0111040
# 009                                           0103000220020
# ...                                                     ...
# 800                     41130530101101010020111000102123100
# 810       1203123247424112130203122344121000014131102231...
# 820                                                  211120
# 830                                                    4500
# 840                                                55400010
#
# [133 rows x 6 columns]

# %%
df['G18USSDKAI'] = df['G18USSDKAI'].map(lambda x: x.replace(',', ''))
df['G18USSRSTE'] = df['G18USSRSTE'].map(lambda x: x.replace(',', ''))
df['G18USSLWAT'] = df['G18USSLWAT'].map(lambda x: x.replace(',', ''))
df['G18USSOWRI'] = df['G18USSOWRI'].map(lambda x: x.replace(',', ''))
#added .loc to account for "copy" warning
#supposed to go index then columns? so might need to add index, which would be ':'
#can just go back if not working
#Df.loc[:,col] Meaning everything in that colun

# %% [markdown]
# **Convert objects to integer** so that they can use groupby and sum
#
# - did it not work?

# %%
df['G18USSDKAI'] = df['G18USSDKAI'].astype(str).astype(int)
df['G18USSRSTE'] = df['G18USSRSTE'].astype(str).astype(int)
df['G18USSLWAT'] = df['G18USSLWAT'].astype(str).astype(int)
df['G18USSOWRI'] = df['G18USSOWRI'].astype(str).astype(int)

# %%
df.head()
# Out:
#                     Pct         LOCALITY  G18USSDKAI  G18USSRSTE  G18USSLWAT  \
# 1    101 - Chincoteague  Accomack County         487         932          16
# 2        201 - Atlantic  Accomack County         159         430          10
# 3  202 - Greenbackville  Accomack County         277         541           7
# 4      301 - New Church  Accomack County         515         447          10
# 5          401 - Bloxom  Accomack County         106         260           4
#
#    G18USSOWRI COUNTYFP
# 1           0      001
# 2           0      001
# 3           1      001
# 4           0      001
# 5           0      001

# %%
final.head()
# Out:
#   COUNTYFP         LOCALITY   VTDST        PRECINCT  G18USSDKAI  G18USSRSTE  \
# 0      001  Accomack County  000101    Chincoteague         556         994
# 1      001  Accomack County  000201        Atlantic         182         459
# 2      001  Accomack County  000202  Greenbackville         316         577
# 3      001  Accomack County  000301      New Church         588         477
# 4      001  Accomack County  000401          Bloxom         121         277
#
#    G18USSLWAT  G18USSOWRI                                           geometry
# 0          17           0  POLYGON Z ((-75.42507 37.89957 0.00000, -75.42...
# 1          11           0  POLYGON Z ((-75.59978 37.87664 0.00000, -75.59...
# 2           8           1  POLYGON Z ((-75.49919 37.93416 0.00000, -75.49...
# 3          11           0  POLYGON Z ((-75.64987 37.92702 0.00000, -75.64...
# 4           4           0  POLYGON Z ((-75.71556 37.87513 0.00000, -75.71...

# %%
groupby_county_df = df.groupby('COUNTYFP').sum()
groupby_county_df
# Out:
#           G18USSDKAI  G18USSRSTE  G18USSLWAT  G18USSOWRI
# COUNTYFP
# 001             5997        6605         135           8
# 003            35701       16371        1161          93
# 005             1952        3433          66           2
# 007             1938        3823          81           7
# 009             4541        7779         215          10
# ...              ...         ...         ...         ...
# 800            21397       13397         461          37
# 810            91813       73575        3851         204
# 820             3849        3713         149           7
# 830             4530        1547         114           9
# 840             5242        3657         210          15
#
# [133 rows x 4 columns]

# %%
groupby_county_final = final.groupby(['COUNTYFP']).sum()
groupby_county_final
# Out:
#           G18USSDKAI  G18USSRSTE  G18USSLWAT  G18USSOWRI
# COUNTYFP
# 001             5997        6605         135           8
# 003            35701       16371        1161          93
# 005             1952        3433          66           2
# 007             1938        3823          81           7
# 009             4541        7779         215          10
# ...              ...         ...         ...         ...
# 800            21397       13397         461          37
# 810            91813       73575        3851         204
# 820             3849        3713         149           7
# 830             4530        1547         114           9
# 840             5242        3657         210          15
#
# [133 rows x 4 columns]

# %%
column_list = ['G18USSDKAI', 'G18USSRSTE', 'G18USSLWAT', 'G18USSOWRI']

# %%
df_final_groupby = pd.merge(groupby_county_df, groupby_county_final, on = 'COUNTYFP', how = 'inner', suffixes = ('_x', '_y'))

# %%
df_final_groupby.head()
# Out:
#           G18USSDKAI_x  G18USSRSTE_x  G18USSLWAT_x  G18USSOWRI_x  \
# COUNTYFP
# 001               5997          6605           135             8
# 003              35701         16371          1161            93
# 005               1952          3433            66             2
# 007               1938          3823            81             7
# 009               4541          7779           215            10
#
#           G18USSDKAI_y  G18USSRSTE_y  G18USSLWAT_y  G18USSOWRI_y
# COUNTYFP
# 001               5997          6605           135             8
# 003              35701         16371          1161            93
# 005               1952          3433            66             2
# 007               1938          3823            81             7
# 009               4541          7779           215            10

# %%
def sum_checker(df, column_list):
    list_max = 0
    for i in column_list:
        left_sum = df[i+'_x'].sum()
        right_sum = df[i+'_y'].sum()
        if (left_sum == right_sum):
            print('column: ', i, ' have the same sums')
        
        else:
            diff = abs(left_sum - right_sum)
            percent = abs(left_sum - right_sum)/left_sum
            print('column: ', i)
            print('RDH sum is ', str(left_sum))
            print('Partner sum is ', str(right_sum))
            print('their (absolute) difference is ', str(diff))
            print('As a percentage of DF1 this is ', str(round(percent*100,5)) + '%')
            if (percent>list_max):
                list_max = percent
            print('')
    print('The max difference (as a percent of the total of on DF column is: ', str(round(list_max,5)))

# %%
sum_checker(df_final_groupby, column_list)
# Out:
# column:  G18USSDKAI  have the same sums
# column:  G18USSRSTE  have the same sums
# column:  G18USSLWAT  have the same sums
# column:  G18USSOWRI  have the same sums
# The max difference (as a percent of the total of on DF column is:  0

# %% [markdown]
# **By county, results match** (great!)
# Now need to re-allocate votes so that it matches by precinct

# %% [markdown]
# First think about for single county single candidate
# - tricky thing is rounding - need to update sum checker to be tolerant of rounding
# - fact that exactly the right number of votes indicates not a consistent rounding method
# - I can just pick a rounding thing now - pick it and move forward -

# %%
def get_absentee_frac(prec_tot, county_tot, absentee_tot):
    '''A spec specifies in first line what function will do
    Returns fraction of county absentee votes for a precinct for a candidate
    
    Keyword arguments: (put inputs to funtions and say what they should be)
    precinct vote total for given candidate (int)
    county vote total for given candidate, absentee and provisional votes not included (int)
    absentee vote total for county for given candidate (int)
    
    "Pure function" bc only relies on inputs and outputs - only variables are ones that were passed as arguments
    '''
    if county_tot != 0:
        prec_frac = prec_tot/county_tot
        absentee_frac = prec_frac*absentee_tot
    else:
        absentee_frac = 0
    return absentee_frac

# %%
absentee_and_prov = df[(df['Pct'].map(lambda x: 'Absentee' in str(x))) | (df['Pct'].map(lambda x: 'Provisional' in str(x)))]
absentee_and_prov
groupby_absentee_and_prov_tot = absentee_and_prov.groupby(['COUNTYFP']).sum()
groupby_absentee_and_prov_tot
# Out:
#           G18USSDKAI  G18USSRSTE  G18USSLWAT  G18USSOWRI
# COUNTYFP
# 001              750         412          10           1
# 003             4082        1332          85          13
# 005              136         156           1           1
# 007              185         295           4           4
# 009              354         395          12           2
# ...              ...         ...         ...         ...
# 800             2067         824          25           4
# 810             8776        6084         250          21
# 820              279         239           6           2
# 830              476         199           0           0
# 840              548         293          20           1
#
# [133 rows x 4 columns]

# %%
groupby_county_df_tot = df.groupby(['COUNTYFP']).sum()
groupby_county_df_tot
# Out:
#           G18USSDKAI  G18USSRSTE  G18USSLWAT  G18USSOWRI
# COUNTYFP
# 001             5997        6605         135           8
# 003            35701       16371        1161          93
# 005             1952        3433          66           2
# 007             1938        3823          81           7
# 009             4541        7779         215          10
# ...              ...         ...         ...         ...
# 800            21397       13397         461          37
# 810            91813       73575        3851         204
# 820             3849        3713         149           7
# 830             4530        1547         114           9
# 840             5242        3657         210          15
#
# [133 rows x 4 columns]

# %% [markdown]
# Need county totals to not includeabsentee/prov ballots to get proper percentage

# %%
df_no_absent_or_provisional = df[(df['Pct'].map(lambda x: 'Absentee' not in str(x))) & (df['Pct'].map(lambda x: 'Provisional' not in str(x)))
                                & (df['LOCALITY'] != 'TOTALS')]
df_no_absent_or_provisional
# Out:
#                        Pct         LOCALITY  G18USSDKAI  G18USSRSTE  \
# 1       101 - Chincoteague  Accomack County         487         932
# 2           201 - Atlantic  Accomack County         159         430
# 3     202 - Greenbackville  Accomack County         277         541
# 4         301 - New Church  Accomack County         515         447
# 5             401 - Bloxom  Accomack County         106         260
# ...                    ...              ...         ...         ...
# 2748   401 - Harwoods Mill      York County         869        1376
# 2749            402 - Dare      York County         836        1437
# 2750         403 - Grafton      York County         509         683
# 2751            501 - Tabb      York County        1052        1369
# 2752          502 - Bethel      York County        1256        1113
#
#       G18USSLWAT  G18USSOWRI COUNTYFP
# 1             16           0      001
# 2             10           0      001
# 3              7           1      001
# 4             10           0      001
# 5              4           0      001
# ...          ...         ...      ...
# 2748          46           5      199
# 2749          35           4      199
# 2750          21           1      199
# 2751          53           6      199
# 2752          53           2      199
#
# [2462 rows x 7 columns]

# %%
groupby_county_tot_no_absentee = df_no_absent_or_provisional.groupby('COUNTYFP').sum()
groupby_county_tot_no_absentee
# Out:
#           G18USSDKAI  G18USSRSTE  G18USSLWAT  G18USSOWRI
# COUNTYFP
# 001             5247        6193         125           7
# 003            31619       15039        1076          80
# 005             1816        3277          65           1
# 007             1753        3528          77           3
# 009             4187        7384         203           8
# ...              ...         ...         ...         ...
# 800            19330       12573         436          33
# 810            83037       67491        3601         183
# 820             3570        3474         143           5
# 830             4054        1348         114           9
# 840             4694        3364         190          14
#
# [133 rows x 4 columns]

# %%
#4/2/21
df_with_absentee_reallocated = df_no_absent_or_provisional.copy()
for index, precinct_total_row_by_candidate in df_no_absent_or_provisional.iterrows():
    #print(precinct_total_row_by_candidate)
    county_fips = precinct_total_row_by_candidate['COUNTYFP']
    county_total_row_by_candidate_no_absentee = groupby_county_tot_no_absentee.loc[county_fips]
    county_absentee_and_provisional_by_candidate = groupby_absentee_and_prov_tot.loc[county_fips]
    #print(precinct_total_row_by_candidate, county_total_row_by_candidate_no_absentee, county_absentee_and_provisional_by_candidate)
    for candidate, votes in county_total_row_by_candidate_no_absentee.to_dict().items():
        prec_tot = precinct_total_row_by_candidate[candidate]
        #print('precinct total: ', prec_tot)
        county_tot = votes
        #print('county total: ', county_tot)
        absentee_tot = county_absentee_and_provisional_by_candidate[candidate]
        #print('absentee total: ', absentee_tot)
        absentee_frac = get_absentee_frac(prec_tot, county_tot, absentee_tot)
        #print('absentee votes to allocate to precinct: ', absentee_frac)
        prec_with_absentee_allocation = prec_tot + absentee_frac
        #print('new precinct total: ', prec_with_absentee_allocation)
        df_with_absentee_reallocated.loc[index, candidate] = round(prec_with_absentee_allocation) #index is row, candidate is column

# %%
df.COUNTYFP.nunique()
# Out:
# 133

# %%
final.COUNTYFP.nunique()
# Out:
# 133

# %%
groupby_df_with_absentee_reallocated = df_with_absentee_reallocated.groupby('COUNTYFP').sum()

# %%
df_absentee_reallocate_with_final = pd.merge(groupby_df_with_absentee_reallocated, groupby_county_final, on = 'COUNTYFP', how = 'inner', suffixes = ('_x', '_y'))

# %%
df_absentee_reallocate_with_final
# Out:
#           G18USSDKAI_x  G18USSRSTE_x  G18USSLWAT_x  G18USSOWRI_x  \
# COUNTYFP
# 001             5999.0        6606.0         136.0           7.0
# 003            35702.0       16371.0        1161.0          90.0
# 005             1952.0        3434.0          65.0           2.0
# 007             1938.0        3823.0          81.0           6.0
# 009             4540.0        7779.0         215.0           9.0
# ...                ...           ...           ...           ...
# 800            21397.0       13398.0         457.0          34.0
# 810            91813.0       73574.0        3851.0         188.0
# 820             3848.0        3714.0         148.0           6.0
# 830             4530.0        1547.0         114.0           9.0
# 840             5242.0        3656.0         211.0          14.0
#
#           G18USSDKAI_y  G18USSRSTE_y  G18USSLWAT_y  G18USSOWRI_y
# COUNTYFP
# 001               5997          6605           135             8
# 003              35701         16371          1161            93
# 005               1952          3433            66             2
# 007               1938          3823            81             7
# 009               4541          7779           215            10
# ...                ...           ...           ...           ...
# 800              21397         13397           461            37
# 810              91813         73575          3851           204
# 820               3849          3713           149             7
# 830               4530          1547           114             9
# 840               5242          3657           210            15
#
# [133 rows x 8 columns]

# %%
sum_checker(df_absentee_reallocate_with_final, column_list)
# Out:
# column:  G18USSDKAI  have the same sums
# column:  G18USSRSTE
# RDH sum is  1374310.0
# Partner sum is  1374313
# their (absolute) difference is  3.0
# As a percentage of DF1 this is  0.00022%
#
# column:  G18USSLWAT
# RDH sum is  61503.0
# Partner sum is  61565
# their (absolute) difference is  62.0
# As a percentage of DF1 this is  0.10081%
#
# column:  G18USSOWRI
# RDH sum is  5361.0
# Partner sum is  5509
# their (absolute) difference is  148.0
# As a percentage of DF1 this is  2.76068%
#
# The max difference (as a percent of the total of on DF column is:  0.02761

# %%
df_with_absentee_reallocated.head()
# Out:
#                     Pct         LOCALITY  G18USSDKAI  G18USSRSTE  G18USSLWAT  \
# 1    101 - Chincoteague  Accomack County       557.0       994.0        17.0
# 2        201 - Atlantic  Accomack County       182.0       459.0        11.0
# 3  202 - Greenbackville  Accomack County       317.0       577.0         8.0
# 4      301 - New Church  Accomack County       589.0       477.0        11.0
# 5          401 - Bloxom  Accomack County       121.0       277.0         4.0
#
#    G18USSOWRI COUNTYFP
# 1         0.0      001
# 2         0.0      001
# 3         1.0      001
# 4         0.0      001
# 5         0.0      001

# %%
final.head()
# Out:
#   COUNTYFP         LOCALITY   VTDST        PRECINCT  G18USSDKAI  G18USSRSTE  \
# 0      001  Accomack County  000101    Chincoteague         556         994
# 1      001  Accomack County  000201        Atlantic         182         459
# 2      001  Accomack County  000202  Greenbackville         316         577
# 3      001  Accomack County  000301      New Church         588         477
# 4      001  Accomack County  000401          Bloxom         121         277
#
#    G18USSLWAT  G18USSOWRI                                           geometry
# 0          17           0  POLYGON Z ((-75.42507 37.89957 0.00000, -75.42...
# 1          11           0  POLYGON Z ((-75.59978 37.87664 0.00000, -75.59...
# 2           8           1  POLYGON Z ((-75.49919 37.93416 0.00000, -75.49...
# 3          11           0  POLYGON Z ((-75.64987 37.92702 0.00000, -75.64...
# 4           4           0  POLYGON Z ((-75.71556 37.87513 0.00000, -75.71...

# %% [markdown]
# Good totals, but inconsistent rounding in final file in cases where vote total has more than 0.5 and less than 0.7

# %% [markdown]
# Note that absolute differences are much better without rouding...

# %%
df_with_absentee_reallocated.shape
# Out:
# (2462, 7)

# %%
final.shape
# Out:
# (2463, 9)

# %% [markdown]
# ### @ Peter
# - how did they round? - by county totals? - Peter rounded to nearest whole number, was fine with things that were 2 votes off for purposes of report

# %% [markdown]
# ### From meeting with Spencer:

# %% [markdown]
# Address geographies before joining with election results
# can clean election results, but need it all to match first
# "Adjust" might not matter for joining election results, but the geometries would be wrong
# if not splitting or merging , could check first
#
# How many precincts in gdf, how many in vest final file?
#
#
# Assume that changes are for all of the files, but for senate legislative districts arent applicaple
# but still need to make modifications for precincts to match
#
# Need sldl and cd from county files as well - pull legislative boundaries from the census to split them
# tigerline - didnt list all county shapfiles - use 2018 file
#
# for special election, sldl should be fine, just pull out district 8 and 24
# does the special file have whole state or just those two districts
#
# number VTDs from vest and from downloaded files

# %% [markdown]
# # Shapefiles: County

# %% [markdown]
# ## Load, Project

# %%
#All counties found: https://www.census.gov/geo/partnerships/pvs/partnership19v2/st51_va.html <-- careful, need to pay close attention to url to makesure get vtds
os.listdir('./vest_va/census_shps_by_county_all_unzip/')
# Out:
# ['partnership_shapefiles_19v2_51580',
#  'partnership_shapefiles_19v2_51117',
#  'partnership_shapefiles_19v2_51121',
#  'partnership_shapefiles_19v2_51119',
#  'partnership_shapefiles_19v2_51770',
#  'partnership_shapefiles_19v2_51181',
#  'partnership_shapefiles_19v2_51175',
#  'partnership_shapefiles_19v2_51143',
#  'partnership_shapefiles_19v2_51520',
#  'partnership_shapefiles_19v2_51127',
#  'partnership_shapefiles_19v2_51740',
#  'partnership_shapefiles_19v2_51111',
#  'partnership_shapefiles_19v2_51145',
#  'partnership_shapefiles_19v2_51510',
#  'partnership_shapefiles_19v2_51187',
#  'partnership_shapefiles_19v2_51173',
#  'partnership_shapefiles_19v2_51001',
#  'partnership_shapefiles_19v2_51650',
#  '.DS_Store',
#  'partnership_shapefiles_19v2_51037',
#  'partnership_shapefiles_19v2_51063',
#  'partnership_shapefiles_19v2_51097',
#  'partnership_shapefiles_19v2_51099',
#  'partnership_shapefiles_19v2_51009',
#  'partnership_shapefiles_19v2_51660',
#  'partnership_shapefiles_19v2_51036',
#  'partnership_shapefiles_19v2_51031',
#  'partnership_shapefiles_19v2_51007',
#  'partnership_shapefiles_19v2_51053',
#  'partnership_shapefiles_19v2_51065',
#  'partnership_shapefiles_19v2_51091',
#  'partnership_shapefiles_19v2_51047',
#  'partnership_shapefiles_19v2_51071',
#  'partnership_shapefiles_19v2_51085',
#  'partnership_shapefiles_19v2_51049',
#  'partnership_shapefiles_19v2_51620',
#  'partnership_shapefiles_19v2_51680',
#  'partnership_shapefiles_19v2_51025',
#  'partnership_shapefiles_19v2_51013',
#  'partnership_shapefiles_19v2_51810',
#  'partnership_shapefiles_19v2_51077',
#  'partnership_shapefiles_19v2_51083',
#  'partnership_shapefiles_19v2_51079',
#  'partnership_shapefiles_19v2_51610',
#  'partnership_shapefiles_19v2_51041',
#  'partnership_shapefiles_19v2_51015',
#  'partnership_shapefiles_19v2_51023',
#  'partnership_shapefiles_19v2_51820',
#  'partnership_shapefiles_19v2_51169',
#  'partnership_shapefiles_19v2_51700',
#  'partnership_shapefiles_19v2_51193',
#  'partnership_shapefiles_19v2_51167',
#  'partnership_shapefiles_19v2_51590',
#  'partnership_shapefiles_19v2_51107',
#  'partnership_shapefiles_19v2_51131',
#  'partnership_shapefiles_19v2_51760',
#  'partnership_shapefiles_19v2_51109',
#  'partnership_shapefiles_19v2_51165',
#  'partnership_shapefiles_19v2_51191',
#  'partnership_shapefiles_19v2_51153',
#  'partnership_shapefiles_19v2_51530']

# %%
#unzip file function
def unzip(path, src_path, dest_path, zip_file_name, unzipped_file_name):
    os.chdir(path)
    with ZipFile(zip_file_name, 'r') as zipObj:
        zipObj.extractall(unzipped_file_name) 
        
    shutil.move(src_path, dest_path)

# %%
#unzip multiple files in directory
def unzip_mult_files(path, new_dir_path):
    if not path[0] == '.':
        os.chdir(path)
        for zipfile in os.listdir():
            if not zipfile[0] == '.' and not zipfile == 'partnership_shapefiles_19v2_51.zip':
                if zipfile.endswith('.zip'): 
                    unzipped_file_name = zipfile[:-4]
                    src_path = os.path.join(path, unzipped_file_name)
                    dest_path = new_dir_path #os.path.join(new_dir_path, unzipped_file_name)
                    unzip(path, src_path, dest_path, zipfile, unzipped_file_name)
                    
'''#test out mult file function - I think it is working - I think embedded folders is product of re-zipping folder?
path = ('/Users/lilyfalk/sandbox/pdv-va/vest_va/test_dir1/')
new_dir_path = '/Users/lilyfalk/sandbox/pdv-va/vest_va/test_dir'
unzip_mult_files(path, new_dir_path)'''
# Out:
# "#test out mult file function - I think it is working - I think embedded folders is product of re-zipping folder?\npath = ('/Users/lilyfalk/sandbox/pdv-va/vest_va/test_dir1/')\nnew_dir_path = '/Users/lilyfalk/sandbox/pdv-va/vest_va/test_dir'\nunzip_mult_files(path, new_dir_path)"

# %%
#unzip files in multiple directories
def unzip_in_mult_directories(path, new_dir_path):
    os.chdir(path)
    for directory in os.listdir():
        if not directory[0] == '.':
            sub_dir = os.path.join(path, directory)
            unzip_mult_files(sub_dir, new_dir_path)
            os.chdir(path)
            
'''
path = '/Users/lilyfalk/sandbox/pdv-va/vest_va/census_shps_by_county_dir_unzip/'
new_dir_path = '/Users/lilyfalk/sandbox/pdv-va/vest_va/census_shps_by_county_all_unzip'
unzip_in_mult_directories(path, new_dir_path)'''

# %% [markdown]
# Now consider how to read in all vtd shapefiles:
# naming convention ex: 'PVS_19_v2_vtd_51650.shp'
# directory convention: 'partnership_shapefiles_19v2_51650"
#
# So, for directory in os.listdir(), read in 'PVS_19_v2_vtd_' + directory[-5:] + '.shp'
# then concatenate all of the files read in, maybe add to dictionary first

# %%
path = ('/Users/lilyfalk/sandbox/pdv-va/vest_va/census_shps_by_county_all_unzip/')
os.chdir(path)
county_fips = []
for directory in os.listdir():
    if not directory[0] == '.':
        county_fips.append(directory[-5:])

# %%
len(county_fips) #As expected
# Out:
# 133

# %%
proj = final.crs

# %%
#Now need function that will read in and concatenate all VTD shapefiles
#Note that last 5 digits of directory and file are state fip (51) plus county fip (3-digit)
path = ('/Users/lilyfalk/sandbox/pdv-va/vest_va/census_shps_by_county_all_unzip/')
os.chdir(path)
county_vtds = []

for i in county_fips: #i dont have fips_codes file
    ref = 'partnership_shapefiles_19v2_'
    vtd_ref = ref + i + '/PVS_19_v2_vtd_' + i + '.shp' 
    vtd_shp = gpd.read_file(vtd_ref)
    print(i, ' added to list')
    county_vtds.append(vtd_shp)
# Out:
# 51580  added to list
# 51117  added to list
# 51121  added to list
# 51119  added to list
# 51770  added to list
# 51181  added to list
# 51175  added to list
# 51143  added to list
# 51520  added to list
# 51127  added to list
# 51740  added to list
# 51111  added to list
# 51145  added to list
# 51510  added to list
# 51187  added to list
# 51173  added to list
# 51001  added to list
# 51650  added to list
# 51037  added to list
# 51063  added to list
# 51097  added to list
# 51099  added to list
# 51009  added to list
# 51660  added to list
# 51036  added to list
# 51031  added to list
# 51007  added to list
# 51053  added to list
# 51065  added to list
# 51091  added to list
# 51047  added to list
# 51071  added to list
# 51085  added to list
# 51049  added to list
# 51620  added to list
# 51680  added to list
# 51025  added to list
# 51013  added to list
# 51810  added to list
# 51077  added to list
# 51083  added to list
# 51079  added to list
# 51610  added to list
# 51041  added to list
# 51015  added to list
# 51023  added to list
# 51820  added to list
# 51169  added to list
# 51700  added to list
# 51193  added to list
# 51167  added to list
# 51133  added to list
# 51550  added to list
# 51595  added to list
# 51105  added to list
# 51159  added to list
# 51730  added to list
# 51195  added to list
# 51161  added to list
# 51157  added to list
# 51103  added to list
# 51135  added to list
# 51790  added to list
# 51720  added to list
# 51149  added to list
# 51171  added to list
# 51185  added to list
# 51147  added to list
# 51570  added to list
# 51113  added to list
# 51125  added to list
# 51141  added to list
# 51710  added to list
# 51179  added to list
# 51177  added to list
# 51183  added to list
# 51775  added to list
# 51540  added to list
# 51115  added to list
# 51093  added to list
# 51067  added to list
# 51600  added to list
# 51069  added to list
# 51051  added to list
# 51005  added to list
# 51830  added to list
# 51033  added to list
# 51057  added to list
# 51095  added to list
# 51061  added to list
# 51630  added to list
# 51059  added to list
# 51690  added to list
# 51035  added to list
# 51800  added to list
# 51003  added to list
# 51670  added to list
# 51019  added to list
# 51683  added to list
# 51021  added to list
# 51017  added to list
# 51840  added to list
# 51043  added to list
# 51081  added to list
# 51075  added to list
# 51011  added to list
# 51678  added to list
# 51640  added to list
# 51029  added to list
# 51685  added to list
# 51027  added to list
# 51087  added to list
# 51073  added to list
# 51089  added to list
# 51045  added to list
# 51137  added to list
# 51750  added to list
# 51139  added to list
# 51101  added to list
# 51155  added to list
# 51199  added to list
# 51163  added to list
# 51735  added to list
# 51197  added to list
# 51590  added to list
# 51107  added to list
# 51131  added to list
# 51760  added to list
# 51109  added to list
# 51165  added to list
# 51191  added to list
# 51153  added to list
# 51530  added to list

# %%
global shapefiles_census
shapefiles_census = gpd.GeoDataFrame(pd.concat(county_vtds, axis = 0) , crs = proj)

# %%
shapefiles_census.plot()

# %%
final.plot()

# %% [markdown]
# ## Dealing with merges

# %% [markdown]
# **From VEST documentation: -- Are these changes to the election result precincts, not to the map?**
#
# The following modifications were made to recreate the 2018 precinct boundaries.
#
# - Albemarle: Add Mechums River to match county GIS shapefile
# - Arlington: Adjust Gunston/Oakridge to match county GIS shapefile
# - Bristol City: Adjust Ward 2/Ward 4 to match description in municipal code
# - Charles City County: Adjust District 1/District 2 boundary to match county code
# - Covington City: Realign Ward 1, Ward 2, Ward 3 to match city PDF map and municipal code
# - Culpeper: Adjust East Fairfax/Brandy Station boundary to match county GIS shapefile
# - Emporia City: Adjust Precincts 1/7, Precincts 2/5 to match municipal code
# - Essex: Adjust South Precinct/Central Precinct boundary to match county PDF
# - Fairfax: Adjust Virginia Run/Bull Run to match county GIS shapefile
# - Fredericksburg City: Adjust District 1/3 boundaries to match municipal code
# - Galax City: Adjust North/South precinct boundary to match municipal GIS shapefile
# - Goochland: Adjust Hadensville/Fife boundary to match description in county code
# - Halifax: Merge South Boston East/West; Adjust Meadville/Republican Grove to match 2011 redistricting PDF map
# - Hampton City: Add US House District 2 segment of Tyler Precinct to match county PDF
# - Hanover: Adjust Blunts/Beaverdam boundary to match county PDF
# - Henry: Adjust 10 precinct boundaries to align VTDs with county GIS shapefile
# - Loudoun: Adjust Weller/Ashbrook, Evergreen/Sycolin Creek; Add Goshen Post, Buffalo Trail to match county GIS shapefile
# - Madison: Adjust all precincts to align VTDs with county GIS shapefile
# - Newport News City: Adjust Sanford/Riverview boundary to match county GIS shapefile
# - Norfolk City: Merge Bramblewood into Chesterfield/Ruffner Academy; Adjust Granby/Titustown to match county PDF
# - Prince William: Adjust Ben Lomond/Mullen, Freedom/Leesylvania to match county GIS shapefile
# - Pulaski: Adjust Dublin/New River to match precinct assignments on county GIS parcel viewer
# - Rappahanock: Adjust Sperryville/Washington boundary to match county PDF
# - Richmond City: Add Precinct 115 to match county GIS shapefile
# - Richmond County: Adjust Precincts 2-1/3-1 boundary to match description in county ordinance
# - Roanoke County: Adjust 12 precinct boundaries to match county GIS shapefile
# - Rockingham: Split East/West Bridgewater to match municipal ordinance; Adjust East Bridgewater to match municipal boundary
# - Russell: Adjust Daugherty/West Lebanon boundary to match county PDF
# - Tazewell: Merge Abbs Valley/Bossevain, Adria/Gap Store, Pounding Mill/Wardell, Raven/Richlands;  Adjust nearly all precinct boundaries to align VTDs with county GIS shapefile
# - Virginia Beach City: Adjust Centerville/Colonial to match county GIS shapefile
# - Williamsburg City: Revise Matoaka/Stryker to match municipal PDF map and municipal code
# - Wise: Adjust Big Stone Gap/East Stone Gap boundary to match county GIS shapefile
# - Wythe: Adjust West Wytheville/East Wytheville boundary to match county GIS shapefile

# %%
shp = shapefiles_census

# %%
shp.shape
# Out:
# (2462, 16)

# %%
final.shape #Great that they are close!
# Out:
# (2463, 9)

# %%
df_with_absentee_reallocated.shape
# Out:
# (2462, 7)

# %% [markdown]
# ### Next step - now that df and final data row counts match more closely
# - need to create unique identifier to match shp, then merge + check geographies...
#   - should I just join shp and df to final file, not worry about unique ID?

# %%
final.head()
# Out:
#   COUNTYFP         LOCALITY   VTDST        PRECINCT  G18USSDKAI  G18USSRSTE  \
# 0      001  Accomack County  000101    Chincoteague         556         994
# 1      001  Accomack County  000201        Atlantic         182         459
# 2      001  Accomack County  000202  Greenbackville         316         577
# 3      001  Accomack County  000301      New Church         588         477
# 4      001  Accomack County  000401          Bloxom         121         277
#
#    G18USSLWAT  G18USSOWRI                                           geometry
# 0          17           0  POLYGON Z ((-75.42507 37.89957 0.00000, -75.42...
# 1          11           0  POLYGON Z ((-75.59978 37.87664 0.00000, -75.59...
# 2           8           1  POLYGON Z ((-75.49919 37.93416 0.00000, -75.49...
# 3          11           0  POLYGON Z ((-75.64987 37.92702 0.00000, -75.64...
# 4           4           0  POLYGON Z ((-75.71556 37.87513 0.00000, -75.71...

# %%
(final.COUNTYFP + final.VTDST.str.slice(start = -3)  + final['PRECINCT']).nunique()
# Out:
# 2463

# %% [markdown]
# Using below method, see that in df,
# - some first characters are getting cut off (ex:'74017 ICTORY LIFE FELLOWSHIP' vs  '740017VICTORY LIFE FELLOWSHIP')
# - inconsistent # of number characters
# - DF some precincts have (CD #) whereas final file does not have this at all
# - some precincts (GLEN FOREST) in DF, not in final and not noted in documentation

# %%
df_unique_id = set((df_with_absentee_reallocated.COUNTYFP + df_with_absentee_reallocated.Pct.str.slice(stop = 3) + df_with_absentee_reallocated.Pct.str.slice(start = 6).map(lambda x: str(x).upper())))

# %%
final_unique_id = set((final.COUNTYFP + final.VTDST.str.slice(start = -3)  + final['PRECINCT'].map(lambda x: str(x).upper())))

# %%
final_unique_id - df_unique_id
# Out:
# {'153307HENDERSON',
#  '153413REAGAN',
#  '750002CENTRAL PRECINCT',
#  '153105LIMESTONE',
#  '059807HUNT VALLEY',
#  '760909NINE HUNDRED NINE',
#  '059401BUSH HILL',
#  '810042BRANDON',
#  '013011EAST FALLS CHURCH',
#  '710306LINDENWOOD',
#  '059301CHAIN BRIDGE',
#  '550022NORFOLK HIGHLANDS',
#  '177602SMITH STATION',
#  '760213TWO HUNDRED THIRTEEN',
#  '087311SHORT PUMP',
#  '087206CENTRAL GARDENS',
#  '149201BLAND',
#  '161403NORTH VINTON',
#  '059329SENECA',
#  '059117WOODSON',
#  '087114MONUMENT HILLS',
#  '800704BURBAGE GRANT',
#  '700213SANFORD',
#  '710215SUBURBAN PARK',
#  '800604WILROY',
#  '590013WARD THIRTEEN',
#  '059932STONE SOUTH',
#  '650108THOMAS',
#  '089502FIGSBORO',
#  '087415SKIPWITH',
#  '630201DISTRICT 2',
#  '059701BLAKE',
#  '095201JAMESTOWN A',
#  '019103CHAMBLISSBURG BAPTIST CHURCH',
#  '087219RANDOLPH',
#  '087314THREE CHOPT',
#  '810032CREEDS',
#  '810004LINKHORN',
#  '810011CAPE HENRY',
#  '775003BEVERLY HEIGHTS',
#  '059802CEDAR LAKE',
#  '610002SECOND WARD',
#  '087207CHAMBERLAYNE',
#  '059850SOUTH RUN',
#  '700316SOUTH MORRISON',
#  '177303RIVERBEND',
#  '059429HYBLA VALLEY',
#  '161302POAGES MILL',
#  '059302CHESTERBROOK',
#  '810084TALLWOOD',
#  '810041COLLEGE PARK',
#  '740023WESTHAVEN BAPTIST CHURCH',
#  '590017WARD SEVENTEEN',
#  '087302CEDARFIELD',
#  '059630ARMY',
#  '087513PLEASANTS',
#  '153410MOUNTAIN VIEW',
#  '177204CHANCELLOR',
#  '095103BERKELEY C',
#  '550015B M WILLIAMS',
#  '153111BRISTOW RUN',
#  '153512YORK',
#  '650217SYMS',
#  '810055MAGIC HOLLOW',
#  '041511BLACK HEATH',
#  '810005SEATACK',
#  '153306WASHINGTON-REID',
#  '059125SIGNAL HILL',
#  '089101BASSETT #2',
#  '059320HERNDON #2',
#  '161108WILDWOOD',
#  '161404SOUTH VINTON',
#  '087109HUNTON',
#  '600003THREE',
#  '095403STONEHOUSE C',
#  '700108LEE HALL',
#  '710511CROSSROADS',
#  '760102ONE HUNDRED TWO',
#  '153202MARSHALL',
#  '810046GREEN RUN',
#  '087309SADLER',
#  '041401HARBOUR POINTE',
#  '059623ALBAN',
#  '061203WARRENTON',
#  '710310ROSEMONT',
#  '700101DENBIGH',
#  '041501HUGUENOT',
#  '013029DOMINION HILLS',
#  '087101COALPIT',
#  '690005PRECINCT #5',
#  '113008CRIGLERSVILLE',
#  '013013GLEN CARLYN',
#  '700202BOULEVARD',
#  '087507ELKO',
#  '041211NASH',
#  '700205DEEP CREEK',
#  '059926POWELL',
#  '810029HOLLAND',
#  '059204MADISON',
#  '760610SIX HUNDRED TEN',
#  '740021JOHN F. KENNEDY COMMUNITY CENTER',
#  '059626SARATOGA',
#  '690001PRECINCT #1',
#  '740011MT. HERMON VILLAGE',
#  '800502HOLLAND',
#  '013007CHERRYDALE',
#  '161105PETERS CREEK',
#  '153106WESTGATE',
#  '153412CATHARPIN',
#  '087111LAKESIDE',
#  '760806EIGHT HUNDRED SIX',
#  '740014BRIGHTON ELEMENTARY SCHOOL',
#  '087515SANDSTON',
#  '710501BAYVIEW',
#  '087404FREEMAN',
#  '013023WESTOVER',
#  '059420VILLAGES',
#  '041505BON AIR',
#  '041210FIVE FORKS',
#  '550047GREEN SEA',
#  '600006SIX',
#  '059216VIENNA #4',
#  '520001FIRST WARD',
#  '760508FIVE HUNDRED EIGHT',
#  '087223YELLOW TAVERN',
#  '775007SOUTH SALEM NO 2',
#  '810094PINEWOOD',
#  '770011RALEIGH COURT',
#  '161104NORTHSIDE',
#  '153505MOHICAN',
#  '059924SPINDLE',
#  '760306THREE HUNDRED SIX',
#  '710102OCEAN VIEW SCHOOL',
#  '550030SOUTH NORFOLK',
#  '019101GOODVIEW ELEM SCHOOL',
#  '600002TWO',
#  '087221STRATFORD HALL',
#  '760301THREE HUNDRED ONE',
#  '149205JEFFERSON PARK',
#  '550032PROVIDENCE',
#  '041518MIDLOTHIAN NORTH',
#  '115003PIANKATANK',
#  '810037CHESAPEAKE BEACH',
#  '059824ORANGE',
#  '019201BEDFORD CHRISTIAN CHURCH',
#  '059227SUNRISE VALLEY',
#  '041301ETTRICK',
#  '059700FAIRFAX COURT',
#  '059930LEES CORNER',
#  '059931CARSON',
#  '550036GREAT BRIDGE BAPTIST CHURCH',
#  '700308JEFFERSON',
#  '059304COOPER',
#  '740032HODGES MANOR ELEMENTARY SCHOOL',
#  '059121VILLA',
#  '650204FORREST',
#  '059118LAKE BRADDOCK',
#  '740001EMANUEL A. M. E. CHURCH',
#  '013016LYON VILLAGE',
#  '059427ISLAND CREEK',
#  '570003THIRD',
#  '089203HORSEPASTURE #2',
#  '153411MULLEN',
#  '550007GREENBRIER',
#  '059225HUGHES',
#  '059509PLAZA',
#  '760113ONE HUNDRED THIRTEEN',
#  '153302POTOMAC',
#  '087209GLEN LEA',
#  '550062FENTRESS',
#  '700307HUNTINGTON',
#  '153607KERRYDALE',
#  '059601BELLE HAVEN',
#  '113003ROCHELLE',
#  '700304CHESTNUT',
#  '820002WARD B',
#  '760603SIX HUNDRED THREE',
#  '550019JOLLIFF',
#  '810097INDIAN RIVER',
#  '177603PIEDMONT',
#  '041208MEADOWBROOK',
#  '710201LARCHMONT SCHOOL',
#  '059910LONDON TOWNE',
#  '087103GLEN ALLEN',
#  '760309THREE HUNDRED NINE',
#  '059916WAPLES MILL',
#  '550046BELLS MILL II',
#  '059604BUCKNELL',
#  '700319SAUNDERS',
#  '087301CAUSEWAY',
#  '550060PARKER ROAD',
#  '013012FAIRLINGTON',
#  '760112ONE HUNDRED TWELVE',
#  '041404PROVIDENCE',
#  '161201PLANTATION',
#  '089404COLLINSVILLE #2',
#  '760409FOUR HUNDRED NINE',
#  '800301WHITE MARSH',
#  '013031LEXINGTON',
#  '059332COATES',
#  '177701BATTLEFIELD',
#  '019203MONETA ELEM SCHOOL',
#  '550050RIVER WALK',
#  '041107WELLS',
#  '770009HIGHLAND',
#  '153109PINEY BRANCH',
#  '550029TANGLEWOOD',
#  '800601LAKESIDE',
#  '059511RAVENWOOD',
#  '059325HUTCHISON',
#  '041514WATKINS',
#  '810013MT TRASHMORE',
#  '013030GLEBE',
#  '710503EAST OCEAN VIEW',
#  '590011WARD ELEVEN',
#  '710402BERKLEY',
#  '059424HUNTLEY',
#  '149105HARRISON',
#  '740013ST. MARK MISSIONARY BAPTIST CHURCH',
#  '760404FOUR HUNDRED FOUR',
#  '013028WAKEFIELD',
#  '550061CENTERVILLE',
#  '800304NANSEMOND RIVER',
#  '059423CLERMONT',
#  '059404FRANCONIA',
#  '041309SKINQUARTER',
#  '059825CHERRY RUN',
#  '650213PHILLIPS',
#  '059223GLADE',
#  '107322BUFFALO TRAIL',
#  '550051COOPERS WAY',
#  '091010HEADWATERS',
#  '161306GARST MILL',
#  '013048AUSA',
#  '059842PARKWAY',
#  '630401DISTRICT 4 - PRECINCT 1',
#  '041203BIRD',
#  '059222RESTON #3',
#  '059331SPRING HILL',
#  '041304WINFREES STORE',
#  '700219DEER PARK',
#  '770001PETERS CREEK',
#  '059209RESTON #2',
#  '760307THREE HUNDRED SEVEN',
#  '740031WEST PARK CHURCH OF CHRIST',
#  '760115ONE HUNDRED FIFTEEN',
#  '059521BROOK HILL',
#  '770002GRANDVIEW',
#  '059720THOREAU',
#  '700315SEDGEFIELD',
#  '550041JOHN T WEST',
#  '041410WAGSTAFF',
#  '013017OVERLEE KNOLLS',
#  '550044NANSEMOND',
#  '087411PEMBERTON',
#  '650201BOOKER',
#  '740026WILLIAM E. WATERS MIDDLE SCHOOL',
#  '059905FRANKLIN',
#  '061103CASANOVA',
#  '153610FITZGERALD',
#  '061101KETTLE RUN',
#  '153711GRAYSON',
#  '041112CARVER',
#  '059233NORTH POINT',
#  '810081ROCK LAKE',
#  '059120SIDEBURN',
#  '059717WOODBURN',
#  '760702SEVEN HUNDRED TWO',
#  '760402FOUR HUNDRED TWO',
#  '550016HICKORY GROVE',
#  '700218KILN CREEK',
#  '153102CEDAR POINT',
#  '087417TUCKAHOE',
#  '013043CAMPBELL',
#  '059523POE',
#  '810027EDWIN',
#  '700107RICHNECK',
#  '810051STRATFORD CHASE',
#  '059115RAVENSWORTH',
#  '810019LAKE SMITH',
#  '059927ARMFIELD',
#  '087313STONEY RUN',
#  '760504FIVE HUNDRED FOUR',
#  '590006WARD SIX',
#  '153712LEESYLVANIA',
#  '710217WESLEY',
#  '760505FIVE HUNDRED FIVE',
#  '810017OCEAN PARK',
#  '087110JOHNSON',
#  '650106ARMSTRONG',
#  '690003PRECINCT #3',
#  '161204BOTETOURT SPRINGS',
#  '810022POINT O VIEW',
#  '153403BULL RUN',
#  '760911NINE HUNDRED ELEVEN',
#  '059607HUNTINGTON',
#  '041502CRESTWOOD',
#  '059628LAUREL HILL',
#  '760509FIVE HUNDRED NINE',
#  '059622LORTON STATION',
#  '059419LANE',
#  '710309NORVIEW',
#  '770013GARDEN CITY',
#  '750001EAST PRECINCT',
#  '550024OAKLETTE',
#  '770019FOREST PARK',
#  '061502NEW BALTIMORE',
#  '019305HUDDLESTON ELEM SCHOOL',
#  '041504ROBIOUS',
#  '760810EIGHT HUNDRED TEN',
#  '019502BIG ISLAND ELEM SCHOOL',
#  "710207LAMBERT'S POINT",
#  '650110PHOEBUS',
#  '710413POPLAR HALLS',
#  '740039CHURCHLAND PRIMARY AND INTERMEDIATE SCHOOL',
#  '089501BASSETT #1',
#  '650115WYTHE',
#  '740037CHURCHLAND MIDDLE SCHOOL',
#  "041212ST. LUKE'S",
#  '087512NINE MILE',
#  '640002NORTH',
#  '810099SALEM WOODS',
#  '760811EIGHT HUNDRED ELEVEN',
#  '710507PRETLOW',
#  '161101CATAWBA',
#  '013025ARLINGTON FOREST',
#  '041406SMOKETREE',
#  '153211SIGNAL HILL',
#  '770015GRANDIN COURT',
#  '087416SPOTTSWOOD',
#  '059518COLUMBIA',
#  '059213VIENNA #1',
#  '153101BRENTSVILLE',
#  '800702HARBOURVIEW',
#  '153511WESTRIDGE',
#  '710406BARRON BLACK',
#  '700209HILTON',
#  '810006ALANTON',
#  '019704BEDFORD CENTRAL LIBRARY',
#  '550003CAMELOT',
#  '700208HIDENWOOD',
#  '059408MOUNT EAGLE',
#  '161103GLENVAR',
#  '059844CENTERPOINTE',
#  '775008EAST SALEM',
#  '153204ELLIS',
#  '095402STONEHOUSE B',
#  '710409FAIRLAWN',
#  '113005MADISON',
#  '177301PLANK ROAD',
#  '041108ECOFF',
#  '740009THIRD BAPTIST CHURCH',
#  '590007WARD SEVEN',
#  '700318WILSON',
#  '153606BEL AIR',
#  '059123ROBINSON',
#  '089204SPENCER',
#  '061201COURTHOUSE',
#  '113006WOLFTOWN',
#  '041307COSBY',
#  '089303IRISBURG',
#  '810049LYNNHAVEN',
#  '650212BETHEL',
#  '177302HAZEL RUN',
#  '013033ROCK SPRING',
#  '041109ELIZABETH SCOTT',
#  '089305MOUNTAIN VALLEY',
#  '153305PATTIE',
#  '113002RADIANT',
#  '013042SHIRLINGTON',
#  '810083STRAWBRIDGE',
#  '153215ROSA PARKS',
#  '019506BOONSBORO RURITAN CLUB',
#  '061403WATERLOO',
#  '041417EDGEWATER',
#  '153605MINNIEVILLE',
#  '177503POST OAK',
#  '061202AIRLIE',
#  '810057SHERRY PARK',
#  '013018PARK LANE',
#  '690006PRECINCT #6',
#  '059735ROTONDA',
#  '153402BATTLEFIELD',
#  '091007MILL GAP',
#  '089602HILLCREST',
#  '700317WASHINGTON',
#  '683004HAYDON',
#  '710412INGLESIDE',
#  '700302BRIARFIELD',
#  '059528RIDGELEA',
#  '550063POPLAR BRANCH',
#  '161102MASON VALLEY',
#  '059333SALONA #2',
#  '059732OAK MARR',
#  '059913ROCKY RUN',
#  '059914VALE',
#  '041101BELLWOOD',
#  '650103CITY HALL',
#  '019505BOONSBORO ELEMENTARY SCHOOL',
#  '570005FIFTH',
#  '153205BUCKHALL',
#  ...}

# %%
df_with_absentee_reallocated.head()
# Out:
#                     Pct         LOCALITY  G18USSDKAI  G18USSRSTE  G18USSLWAT  \
# 1    101 - Chincoteague  Accomack County       557.0       994.0        17.0
# 2        201 - Atlantic  Accomack County       182.0       459.0        11.0
# 3  202 - Greenbackville  Accomack County       317.0       577.0         8.0
# 4      301 - New Church  Accomack County       589.0       477.0        11.0
# 5          401 - Bloxom  Accomack County       121.0       277.0         4.0
#
#    G18USSOWRI COUNTYFP
# 1         0.0      001
# 2         0.0      001
# 3         1.0      001
# 4         0.0      001
# 5         0.0      001

# %%
(df_with_absentee_reallocated.COUNTYFP + df_with_absentee_reallocated.Pct.str.slice(stop = 3)).nunique()# + df_with_absentee_reallocated.Pct.str.slice(start = 6)).nunique()
# Out:
# 2440

# %%
shp.head()
# Out:
#   STATEFP COUNTYFP   VTDST      NAMELSAD VTDI LSAD CHNG_TYPE ORIG_NAME  \
# 0      51      580  000101  Precinct 1-1    A   00      None      None
# 1      51      580  000201  Precinct 2-1    A   00      None      None
# 2      51      580  000301  Precinct 3-1    A   00      None      None
# 3      51      580  000401  Precinct 4-1    A   00      None      None
# 4      51      580  000501  Precinct 5-1    A   00      None      None
#
#   ORIG_CODE RELATE          NAME VINTAGE FUNCSTAT JUSTIFY  MTFCC  \
# 0      None   None  Precinct 1-1      90        N    None  G5240
# 1      None   None  Precinct 2-1      90        N    None  G5240
# 2      None   None  Precinct 3-1      90        N    None  G5240
# 3      None   None  Precinct 4-1      90        N    None  G5240
# 4      None   None  Precinct 5-1      90        N    None  G5240
#
#                                             geometry
# 0  POLYGON Z ((-80.00136 37.78983 0.00000, -80.00...
# 1  POLYGON Z ((-79.99129 37.79115 0.00000, -79.99...
# 2  POLYGON Z ((-79.99661 37.78701 0.00000, -79.99...
# 3  POLYGON Z ((-79.99797 37.78069 0.00000, -79.99...
# 4  POLYGON Z ((-80.00899 37.76259 0.00000, -80.00...

# %%
(df_with_absentee_reallocated.COUNTYFP + df_with_absentee_reallocated.Pct.str.slice(stop = 3)).value_counts()
# Out:
# 800404    2
# 153312    2
# 095202    2
# 55020     2
# 177402    2
#          ..
# 087407    1
# 171601    1
# 089401    1
# 0133 -    1
# 087507    1
# Length: 2440, dtype: int64

# %% [markdown]
# Peter + Izzy 4/6/21
# - import congressional shapefiles, assign the overlap as the new shapefile
# - create list of vtds where not unique
# - join ones that do work with county and vtdst
#     - print out ones that dont match and manually match them up
#     - right now in election and shapefile could create column with county fip, vtdst
#     filter out ones that repeat entirely
#     remaining ones join manually in mini df
#     then join the two dfs - could create a dictionary to map from nonunique to temporary unique one - adding a or b to end of it,
# - set indicator to true in merge to show whether merged
#
# oin_elec_geom1 = pd.merge(wa_geo,revised_df,on='FULLPRC',how='outer',indicator=True)
#
# false = join_elec_geom1[join_elec_geom1['_merge']!='both'].copy()

# %% [markdown]
# See that in case of df, the overlap, value_counts > 1 are result of same precinct name, different CD

# %%
df_with_absentee_reallocated[(df_with_absentee_reallocated.Pct.str.slice(stop = 3) == '304') & (df_with_absentee_reallocated.COUNTYFP == '089')]
# Out:
#                             Pct      LOCALITY  G18USSDKAI  G18USSRSTE  \
# 1316  304 - Mount Olivet (CD 5)  Henry County       718.0       564.0
# 1317  304 - Mount Olivet (CD 9)  Henry County         4.0         0.0
#
#       G18USSLWAT  G18USSOWRI COUNTYFP
# 1316         8.0         0.0      089
# 1317         0.0         0.0      089

# %%
df_county_vtdst = set(df_with_absentee_reallocated.COUNTYFP + df_with_absentee_reallocated.Pct.str.slice(stop = 3))
df_county_vtdst
# Out:
# {'107505',
#  '179103',
#  '187102',
#  '029301',
#  '085603',
#  '7503 -',
#  '800501',
#  '5901 -',
#  '143705',
#  '710415',
#  '800601',
#  '760703',
#  '061404',
#  '005601',
#  '059612',
#  '173501',
#  '760308',
#  '153203',
#  '181401',
#  '015501',
#  '74014 ',
#  '051303',
#  '6002 -',
#  '153610',
#  '059223',
#  '149204',
#  '015202',
#  '036301',
#  '760702',
#  '153604',
#  '059711',
#  '035102',
#  '81089 ',
#  '650202',
#  '121602',
#  '059240',
#  '059910',
#  '167101',
#  '107213',
#  '760208',
#  '650105',
#  '041405',
#  '59011 ',
#  '630401',
#  '059804',
#  '7752 -',
#  '01321 ',
#  '011201',
#  '059331',
#  '760101',
#  '510302',
#  '059920',
#  '003106',
#  '047602',
#  '059501',
#  '730301',
#  '760207',
#  '031303',
#  '067201',
#  '089101',
#  '019302',
#  '165405',
#  '041501',
#  '041513',
#  '0917 -',
#  '041201',
#  '059422',
#  '005502',
#  '051202',
#  '6006 -',
#  '5704 -',
#  '077107',
#  '059903',
#  '7753 -',
#  '161403',
#  '073202',
#  '153103',
#  '165101',
#  '153311',
#  '179203',
#  '087204',
#  '069202',
head()
# Out:
#   COUNTYFP         LOCALITY   VTDST        PRECINCT  G18USSDKAI  G18USSRSTE  \
# 0      001  Accomack County  000101    Chincoteague         556         994
# 1      001  Accomack County  000201        Atlantic         182         459
# 2      001  Accomack County  000202  Greenbackville         316         577
# 3      001  Accomack County  000301      New Church         588         477
# 4      001  Accomack County  000401          Bloxom         121         277
#
#    G18USSLWAT  G18USSOWRI                                           geometry
# 0          17           0  POLYGON Z ((-75.42507 37.89957 0.00000, -75.42...
# 1          11           0  POLYGON Z ((-75.59978 37.87664 0.00000, -75.59...
# 2           8           1  POLYGON Z ((-75.49919 37.93416 0.00000, -75.49...
# 3          11           0  POLYGON Z ((-75.64987 37.92702 0.00000, -75.64...
# 4           4           0  POLYGON Z ((-75.71556 37.87513 0.00000, -75.71...

# %%
final_county_vtdst = set(final.COUNTYFP + final.VTDST.str.slice(start = 3))
shp_county_vtdst - final_county_vtdst
# Out:
# {'003407',
#  '003507',
#  '041113',
#  '041216',
#  '041314',
#  '041319',
#  '041412',
#  '077011',
#  '077012',
#  '095041',
#  '095042',
#  '121032',
#  '153061',
#  '153062',
#  '153114',
#  '153315',
#  '161401',
#  '191021',
#  '191022',
#  '510112',
#  '510309',
#  '520041',
#  '520042',
#  '550064',
#  '550065',
#  '685031',
#  '685032',
#  '750004',
#  '760215',
#  '760415'}

# %% [markdown]
# See below with unique IDs are missing

# %%
pd.set_option("display.max_rows", 101)

# %%
double_vtdst = (final.COUNTYFP + final.VTDST.str.slice(start = 3)).value_counts()

# %%
double_vtdst[double_vtdst > 1].index
# Out:
# Index(['800302', '800504', '153210', '153112', '177704', '550020', '800602',
#        '710104', '177103', '800404', '153312', '177703', '177702', '095504',
#        '177402', '153609', '059513', '153110', '650215', '089505', '089304',
#        '095202'],
#       dtype='object')

# %%
nonunique_id = ['650215', '177703', '089304', '177402', '800602', '153112', '059513',
       '800504', '095202', '800404', '550020', '089505', '800302', '153609',
       '153210', '177103', '710104', '153110', '177702', '095504', '153312',
       '177704']

# %%
final['unique_id'] = final.COUNTYFP + final.VTDST.str.slice(start = 3)

# %%
final[final['unique_id'].isin(nonunique_id)]
# Out:
#      COUNTYFP               LOCALITY   VTDST                    PRECINCT  \
# 1803      650           Hampton City  000215                TYLER (CD 3)
# 2232      550        Chesapeake City  000020          E W Chittum (CD 4)
# 2233      550        Chesapeake City  000020          E W Chittum (CD 3)
# 2234      059         Fairfax County  000513         Saint Albans (CD 8)
# 2235      059         Fairfax County  000513        Saint Albans (CD 11)
# 2239      650           Hampton City  000215                TYLER (CD 2)
# 2241      095      James City County  000504            Roberts D (CD 1)
# 2242      095      James City County  000504            Roberts D (CD 2)
# 2267      710           Norfolk City  000104            Titustown (CD 2)
# 2268      710           Norfolk City  000104            Titustown (CD 3)
# 2270      153  Prince William County  000210                 Penn (CD 1)
# 2271      153  Prince William County  000210                Penn (CD 11)
# 2272      153  Prince William County  000110       Buckland Mills (CD 1)
# 2273      153  Prince William County  000112        Burke-Nickens (CD 1)
# 2274      153  Prince William County  000112       Burke-Nickens (CD 10)
# 2275      153  Prince William County  000110      Buckland Mills (CD 10)
# 2276      153  Prince William County  000312            Triangle (CD 11)
# 2277      153  Prince William County  000312             Triangle (CD 1)
# 2278      153  Prince William County  000609                King (CD 11)
# 2279      153  Prince William County  000609                 King (CD 1)
# 2284      177    Spotsylvania County  000703             Fairview (CD 7)
# 2285      177    Spotsylvania County  000704                Gayle (CD 1)
# 2286      177    Spotsylvania County  000703             Fairview (CD 1)
# 2287      177    Spotsylvania County  000402             Parkside (CD 7)
OCALITY  G18USSDKAI  G18USSRSTE  G18USSLWAT  \
# 1    101 - Chincoteague  Accomack County       557.0       994.0        17.0
# 2        201 - Atlantic  Accomack County       182.0       459.0        11.0
# 3  202 - Greenbackville  Accomack County       317.0       577.0         8.0
# 4      301 - New Church  Accomack County       589.0       477.0        11.0
# 5          401 - Bloxom  Accomack County       121.0       277.0         4.0
#
#    G18USSOWRI COUNTYFP
# 1         0.0      001
# 2         0.0      001
# 3         1.0      001
# 4         0.0      001
# 5         0.0      001

# %%
final[(final.VTDST.str.slice(start = 3) == '215') & (final.COUNTYFP == '650')]
# Out:
#      COUNTYFP      LOCALITY   VTDST      PRECINCT  G18USSDKAI  G18USSRSTE  \
# 1803      650  Hampton City  000215  TYLER (CD 3)         363          62
# 2239      650  Hampton City  000215  TYLER (CD 2)          38           9
#
#       G18USSLWAT  G18USSOWRI  \
# 1803          10           5
# 2239           1           0
#
#                                                geometry unique_id
# 1803  POLYGON Z ((-76.36283 37.05127 0.00000, -76.36...    650215
# 2239  POLYGON Z ((-76.36144 37.05458 0.00000, -76.35...    650215

# %%
final[(final.VTDST.str.slice(start = 3) == '215') & (final.COUNTYFP == '650')]
# Out:
#      COUNTYFP      LOCALITY   VTDST      PRECINCT  G18USSDKAI  G18USSRSTE  \
# 1803      650  Hampton City  000215  TYLER (CD 3)         363          62
# 2239      650  Hampton City  000215  TYLER (CD 2)          38           9
#
#       G18USSLWAT  G18USSOWRI  \
# 1803          10           5
# 2239           1           0
#
#                                                geometry unique_id
# 1803  POLYGON Z ((-76.36283 37.05127 0.00000, -76.36...    650215
# 2239  POLYGON Z ((-76.36144 37.05458 0.00000, -76.35...    650215

# %% [markdown]
# See that in case of final, the overlap, value_counts > 1 are also result of same precinct name, different CD
#
# so, make new column - merge rows that match? or leave them? ~100 cases where merge would need to occur...
#
# To do that, do
# - if county_vtdst appears twice
#     - merge election results (+)
#     - PRECINCT name = PRECINCT.str.slice(stop = -7)
#
#
# ignore for now:
# for index, candidate in df.iterrows():
#     if county_vtdst

# %%
df_with_absentee_reallocated.Pct.str.slice(stop = 3)
# Out:
# 1       101
# 2       201
# 3       202
# 4       301
# 5       401
#        ...
# 2748    401
# 2749    402
# 2750    403
# 2751    501
# 2752    502
# Name: Pct, Length: 2462, dtype: object

# %%
df_with_absentee_reallocated['vtdst'] = df_with_absentee_reallocated.Pct.str.slice(stop = 3)

# %%
#Now, tackle the case where vtdst messed up in df - add vtdst column
def vtdst_changer(vtdst):
    if (vtdst[1:3] == ' -'):
        two_lead_zero = '00' + vtdst[:1]
        return two_lead_zero
    elif (vtdst[1:3] == '- '):
        two_lead_zero = '00' + vtdst[:1]
        return two_lead_zero
    elif (vtdst[-1:] == ' '):
        one_lead_zero = '0' + vtdst[:2]
        return one_lead_zero
    elif (vtdst[-1:] == '-'):
        one_lead_zero = '0' + vtdst[:2]
        return one_lead_zero
    else:
        return vtdst

# %%
df_with_absentee_reallocated['vtdst'] = df_with_absentee_reallocated['vtdst'].apply(vtdst_changer)
df_with_absentee_reallocated.head()
# Out:
#                     Pct         LOCALITY  G18USSDKAI  G18USSRSTE  G18USSLWAT  \
# 1    101 - Chincoteague  Accomack County       557.0       994.0        17.0
# 2        201 - Atlantic  Accomack County       182.0       459.0        11.0
# 3  202 - Greenbackville  Accomack County       317.0       577.0         8.0
# 4      301 - New Church  Accomack County       589.0       477.0        11.0
# 5          401 - Bloxom  Accomack County       121.0       277.0         4.0
#
#    G18USSOWRI COUNTYFP vtdst
# 1         0.0      001   101
# 2         0.0      001   201
# 3         1.0      001   202
# 4         0.0      001   301
# 5         0.0      001   401

# %%
((df_with_absentee_reallocated['COUNTYFP']+ df_with_absentee_reallocated['vtdst'])).nunique()
# Out:
# 2440

# %%
(df_with_absentee_reallocated['COUNTYFP'] + df_with_absentee_reallocated['Pct'].str.slice(stop = 3)).nunique()
# Out:
# 2440

# %%
df_with_absentee_reallocated[df_with_absentee_reallocated['vtdst'].str.slice(start = -1) == '-']
# Out:
# Empty DataFrame
# Columns: [Pct, LOCALITY, G18USSDKAI, G18USSRSTE, G18USSLWAT, G18USSOWRI, COUNTYFP, vtdst]
# Index: []

# %% [markdown]
# Now, with vtdst in each set, make unique ID from the 2440 that do match, then account for the 10/20 that dont afterward.

# %%
df_with_absentee_reallocated['vtdst'].nunique()
# Out:
# 379

# %%
final['VTDST'].str.slice(start = 3).nunique()
# Out:
# 382

# %%
shp['VTDST'].str.slice(start = 3).nunique()
# Out:
# 380

# %%
set(final['VTDST'].str.slice(start = 3)) - set(shp['VTDST'].str.slice(start = 3))
# Out:
# {'499', '599'}

# %%
set(final['VTDST'].str.slice(start = 3)) - set(df_with_absentee_reallocated['vtdst'])
# Out:
# {'499', '599', '700'}

# %%
set(shp['VTDST'].str.slice(start = 3)) - set(df_with_absentee_reallocated['vtdst'])
# Out:
# {'700'}

# %%
final[final['VTDST'].str.slice(start = 3) == '700']
# Out:
#     COUNTYFP        LOCALITY   VTDST       PRECINCT  G18USSDKAI  G18USSRSTE  \
# 600      059  Fairfax County  000700  Fairfax Court           0           0
#
#      G18USSLWAT  G18USSOWRI  \
# 600           0           0
#
#                                               geometry unique_id
# 600  POLYGON Z ((-77.31648 38.84615 0.00000, -77.31...    059700

# %%
final[final['VTDST'].str.slice(start = 3) == '599']
# Out:
#      COUNTYFP          LOCALITY   VTDST PRECINCT  G18USSDKAI  G18USSRSTE  \
# 2332      003  Albemarle County  000599  Pantops        1054         453
#
#       G18USSLWAT  G18USSOWRI  \
# 2332          23           2
#
#                                                geometry unique_id
# 2332  POLYGON Z ((-78.45505 38.04404 0.00000, -78.45...    003599

# %%
final[final['VTDST'].str.slice(start = 3) =='499']
# Out:
#    COUNTYFP          LOCALITY   VTDST     PRECINCT  G18USSDKAI  G18USSRSTE  \
# 29      003  Albemarle County  000499  Biscuit Run        1083         252
#
#     G18USSLWAT  G18USSOWRI                                           geometry  \
# 29          47           2  POLYGON Z ((-78.53848 37.98576 0.00000, -78.53...
#
#    unique_id
# 29    003499

# %%
df_with_absentee_reallocated['unique_id'] = df_with_absentee_reallocated['COUNTYFP'] + df_with_absentee_reallocated['vtdst']

# %%
double_in_df = df_with_absentee_reallocated['unique_id'].value_counts()
df_double_list = double_in_df[double_in_df > 1].index

# %%
final_double_list = double_vtdst[double_vtdst > 1].index

# %%
set(final_double_list) - set(df_double_list)
# Out:
# set()

# %%
(df_double_list)
# Out:
# Index(['177704', '089304', '177703', '153210', '800602', '550020', '153112',
#        '177402', '153609', '177702', '800504', '095504', '095202', '177103',
#        '153312', '710104', '153110', '800302', '089505', '650215', '800404',
#        '059513'],
#       dtype='object')

# %%
final['PRECINCT'].str.slice(start = -6)[final['unique_id'].isin(list(df_double_list))]
# Out:
# 1803    (CD 3)
# 2232    (CD 4)
# 2233    (CD 3)
# 2234    (CD 8)
# 2235    CD 11)
# 2239    (CD 2)
# 2241    (CD 1)
# 2242    (CD 2)
# 2267    (CD 2)
# 2268    (CD 3)
# 2270    (CD 1)
# 2271    CD 11)
# 2272    (CD 1)
# 2273    (CD 1)
# 2274    CD 10)
# 2275    CD 10)
# 2276    CD 11)
# 2277    (CD 1)
# 2278    CD 11)
# 2279    (CD 1)
# 2284    (CD 7)
# 2285    (CD 1)
# 2286    (CD 1)
# 2287    (CD 7)
# 2288    (CD 1)
# 2289    (CD 7)
# 2290    (CD 1)
# 2291    (CD 7)
# 2292    (CD 7)
# 2293    (CD 1)
# 2294    (CD 4)
# 2295    (CD 4)
# 2296    (CD 3)
# 2297    (CD 4)
# 2298    (CD 3)
# 2299    (CD 4)
# 2300    (CD 3)
# 2301    (CD 3)
# 2302    (CD 1)
# 2303    (CD 2)
# 2313    (CD 9)
# 2314    (CD 5)
# 2315    (CD 5)
# 2316    (CD 9)
# Name: PRECINCT, dtype: object

# %%
def vtdst_add_cd(unique_id, precinct):
    double_list = ['177702', '153112', '710104', '800602', '095504', '177103', '089505',
       '800404', '800504', '153210', '095202', '089304', '800302', '153609',
       '177703', '650215', '177402', '153312', '059513', '550020', '177704',
       '153110']
    if (unique_id in double_list):
        unique_id = unique_id + precinct[-6:]
        return unique_id
    else:
        return unique_id

# %%
df_with_absentee_reallocated['unique_id_1'] = df_with_absentee_reallocated.apply(lambda row: vtdst_add_cd(row['unique_id'], row['Pct']), axis = 1)

# %%
df_with_absentee_reallocated['unique_id_1'].nunique()
# Out:
# 2462

# %%
final['unique_id_1'] = final.apply(lambda row: vtdst_add_cd(row['unique_id'], row['PRECINCT']), axis = 1)

# %%
df_with_absentee_reallocated['unique_id_1'][df_with_absentee_reallocated['unique_id'].isin(list(df_double_list))]
# Out:
# 425     550020(CD 3)
# 426     550020(CD 4)
# 787     059513CD 11)
# 788     059513(CD 8)
# 1157    650215(CD 2)
# 1158    650215(CD 3)
# 1316    089304(CD 5)
# 1317    089304(CD 9)
# 1327    089505(CD 5)
# 1328    089505(CD 9)
# 1374    095202(CD 1)
# 1375    095202(CD 2)
# 1388    095504(CD 1)
# 1389    095504(CD 2)
# 1764    710104(CD 2)
# 1765    710104(CD 3)
# 2001    153110(CD 1)
# 2002    153110CD 10)
# 2004    153112(CD 1)
# 2005    153112CD 10)
# 2015    153210(CD 1)
# 2016    153210CD 11)
# 2033    153312(CD 1)
# 2034    153312CD 11)
# 2072    153609(CD 1)
# 2073    153609CD 11)
# 2402    177103(CD 1)
# 2403    177103(CD 7)
# 2413    177402(CD 1)
# 2414    177402(CD 7)
# 2425    177702(CD 1)
# 2426    177702(CD 7)
# 2427    177703(CD 1)
# 2428    177703(CD 7)
# 2429    177704(CD 1)
# 2430    177704(CD 7)
# 2479    800302(CD 3)
# 2480    800302(CD 4)
# 2486    800404(CD 3)
# 2487    800404(CD 4)
# 2491    800504(CD 3)
# 2492    800504(CD 4)
# 2494    800602(CD 3)
# 2495    800602(CD 4)
# Name: unique_id_1, dtype: object

# %%
set(final['unique_id_1']) - set(df_with_absentee_reallocated['unique_id_1'])
# Out:
# {'003499', '003599', '059700'}

# %% [markdown]
# Next, apply change to shp file, make unique ids, merge, check results.

# %%
shp['unique_id'] = shp['COUNTYFP'] + shp['VTDST'].str.slice(start = 3)

# %%
shp.shape
# Out:
# (2462, 17)

# %%
df_notin_shp = list(set(df_with_absentee_reallocated['unique_id']) - set(shp['unique_id']))

# %%
df_with_absentee_reallocated[df_with_absentee_reallocated['unique_id'].isin(df_notin_shp)]
# Out:
#                           Pct               LOCALITY  G18USSDKAI  G18USSRSTE  \
# 278           4 - Fourth Ward           Bristol City       610.0      1581.0
# 446   40 - River Birch (CD 3)        Chesapeake City      1235.0       760.0
# 453     47 - Green Sea (CD 4)        Chesapeake City       305.0       509.0
# 1086              401 - Fries         Grayson County       101.0       224.0
# 1372   104- Berkeley D (CD 2)      James City County       457.0       318.0
# 1616       3 - Precinct Three     Manassas Park City       953.0       464.0
# 1997    106 - Westgate (CD 1)  Prince William County       976.0       265.0
# 2681            702 - Wallace      Washington County       132.0       449.0
#
#       G18USSLWAT  G18USSOWRI COUNTYFP vtdst unique_id unique_id_1
# 278         24.0         2.0      520   004    520004      520004
# 446         29.0         3.0      550   040    550040      550040
# 453         15.0         2.0      550   047    550047      550047
# 1086         4.0         0.0      077   401    077401      077401
# 1372        19.0         1.0      095   104    095104      095104
# 1616        28.0         0.0      685   003    685003      685003
# 1997        26.0         2.0      153   106    153106      153106
# 2681         7.0         1.0      191   702    191702      191702

# %%
shp_notin_df = list(set(shp['unique_id']) - set(df_with_absentee_reallocated['unique_id']))
shp[shp['unique_id'].isin(shp_notin_df)]
# Out:
#     STATEFP COUNTYFP   VTDST                            NAMELSAD VTDI LSAD  \
# 23       51      121  002032                          B-3 part 2    A   00
# 24       51      121  004032                          D-3 part 2    A   00
# 3        51      520  000041  Fourth Ward Part 1 Voting District    P   V2
# 4        51      520  000042  Fourth Ward Part 2 Voting District    P   V2
# 20       51      510  000112          Alex Renew Voting District    A   V2
# 21       51      510  000309       Olympus Condo Voting District    A   V2
# 14       51      077  004011        Fries Part 1 Voting District    P   V2
# 15       51      077  004012        Fries Part 2 Voting District    P   V2
# 13       51      041  000113   Iron Bridge North Voting District    A   V2
# 14       51      041  000216           Ridgedale Voting District    A   V2
# 42       51      041  000319            Magnolia Voting District    A   V2
# 45       51      041  000412         Clover Hill Voting District    A   V2
# 47       51      041  000314           LongHouse Voting District    A   V2
# 56       51      550  000065         Waterway II Voting District    A   V2
# 62       51      550  000064       Deep Creek II Voting District    A   V2
# 23       51      161  000401                    South Lindenwood    A   00
# 17       51      095  001042   Berkeley D Part 2 Voting District    P   V2
# 19       51      095  001041   Berkeley D Part 1 Voting District    P   V2
# 152      51      059  000700       Fairfax Court Voting District    A   V2
# 2        51      685  000031               Precinct Three Part 1    P   00
# 3        51      685  000032               Precinct Three Part 2    P   00
# 3        51      750  000004                  New River Precinct    A   00
# 20       51      760  000215                                 215    A   00
# 21       51      760  000415                                 415    A   00
# 18       51      191  007021      WALLACE PART 1 Voting District    A   V2
# 19       51      191  007022      WALLACE PART 2 Voting District    A   V2
# 12       51      153  000114        Piney Branch Voting District    A   V2
# 38       51      153  000315            Williams Voting District    A   V2
# 83       51      153  001061            Westgate Voting District    A   V2
# 84       51      153  001062     Westgate Part 2 Voting District    A   V2
#
#     CHNG_TYPE ORIG_NAME ORIG_CODE RELATE                   NAME VINTAGE  \
# 23       None      None      None   None             B-3 part 2      90
# 24       None      None      None   None             D-3 part 2      90
# 3        None      None      None   None     Fourth Ward Part 1      90
# 4        None      None      None   None     Fourth Ward Part 2      90
# 20       None      None      None   None             Alex Renew      90
# 21       None      None      None   None          Olympus Condo      90
# 14       None      None      None   None           Fries Part 1      90
# 15       None      None      None   None           Fries Part 2      90
# 13       None      None      None   None      Iron Bridge North      90
# 14       None      None      None   None              Ridgedale      90
# 42       None      None      None   None               Magnolia      90
# 45       None      None      None   None            Clover Hill      90
# 47       None      None      None   None              LongHouse      90
# 56       None      None      None   None            Waterway II      90
# 62       None      None      None   None          Deep Creek II      90
# 23       None      None      None   None       South Lindenwood      90
# 17       None      None      None   None      Berkeley D Part 2      90
# 19       None      None      None   None      Berkeley D Part 1      90
# 152      None      None      None   None          Fairfax Court      90
# 2        None      None      None   None  Precinct Three Part 1      90
# 3        None      None      None   None  Precinct Three Part 2      90
# 3        None      None      None   None     New River Precinct      90
# 20       None      None      None   None                    215      90
# 21       None      None      None   None                    415      90
# 18       None      None      None   None         WALLACE PART 1      90
# 19       None      None      None   None         WALLACE PART 2      90
# 12       None      None      None   None           Piney Branch      90
# 38       None      None      None   None               Williams      90
# 83       None      None      None   None               Westgate      90
# 84       None      None      None   None        Westgate Part 2      90
#
#     FUNCSTAT JUSTIFY  MTFCC  \
# 23         N    None  G5240
# 24         N    None  G5240
# 3          S    None  G5240
# 4          S    None  G5240
# 20         N    None  G5240
# 21         N    None  G5240
# 14         S    None  G5240
# 15         S    None  G5240
# 13         N    None  G5240
# 14         N    None  G5240
# 42         N    None  G5240
# 45         N    None  G5240
# 47         N    None  G5240
# 56         N    None  G5240
# 62         N    None  G5240
# 23         N    None  G5240
# 17         S    None  G5240
# 19         S    None  G5240
# 152        N    None  G5240
# 2          S    None  G5240
# 3          S    None  G5240
# 3          N    None  G5240
# 20         N    None  G5240
# 21         N    None  G5240
# 18         N    None  G5240
# 19         N    None  G5240
# 12         N    None  G5240
# 38         N    None  G5240
# 83         N    None  G5240
# 84         N    None  G5240
#
#                                               geometry unique_id
# 23   POLYGON Z ((-80.44921 37.16344 0.00000, -80.44...    121032
# 24   POLYGON Z ((-80.51937 37.13193 0.00000, -80.51...    121032
# 3    POLYGON Z ((-82.16028 36.62071 0.00000, -82.15...    520041
# 4    POLYGON Z ((-82.12869 36.64952 0.00000, -82.12...    520042
# 20   POLYGON Z ((-77.07746 38.80083 0.00000, -77.07...    510112
# 21   POLYGON Z ((-77.14368 38.81340 0.00000, -77.14...    510309
# 14   POLYGON Z ((-81.08851 36.76885 0.00000, -81.08...    077011
# 15   POLYGON Z ((-81.01449 36.70041 0.00000, -81.01...    077012
# 13   POLYGON Z ((-77.50202 37.37361 0.00000, -77.50...    041113
# 14   POLYGON Z ((-77.53608 37.41786 0.00000, -77.53...    041216
# 42   POLYGON Z ((-77.87842 37.38274 0.00000, -77.87...    041319
# 45   POLYGON Z ((-77.65441 37.46063 0.00000, -77.65...    041412
# 47   POLYGON Z ((-77.56894 37.28089 0.00000, -77.56...    041314
# 56   POLYGON Z ((-76.20982 36.74850 0.00000, -76.20...    550065
# 62   POLYGON Z ((-76.49148 36.55072 0.00000, -76.48...    550064
# 23   POLYGON Z ((-79.88106 37.26168 0.00000, -79.88...    161401
# 17   POLYGON Z ((-76.75418 37.24672 0.00000, -76.75...    095042
# 19   POLYGON Z ((-76.79774 37.21409 0.00000, -76.79...    095041
# 152  POLYGON Z ((-77.31648 38.84615 0.00000, -77.31...    059700
# 2    POLYGON Z ((-77.45337 38.76934 0.00000, -77.45...    685031
# 3    POLYGON Z ((-77.43817 38.75879 0.00000, -77.43...    685032
# 3    POLYGON Z ((-80.55374 37.14115 0.00000, -80.55...    750004
# 20   POLYGON Z ((-77.48355 37.57346 0.00000, -77.48...    760215
# 21   POLYGON Z ((-77.58100 37.53244 0.00000, -77.58...    760415
# 18   POLYGON Z ((-82.14454 36.66976 0.00000, -82.14...    191021
# 19   POLYGON Z ((-82.15066 36.67508 0.00000, -82.15...    191022
# 12   POLYGON Z ((-77.62180 38.76333 0.00000, -77.62...    153114
# 38   POLYGON Z ((-77.32258 38.58021 0.00000, -77.32...    153315
# 83   POLYGON Z ((-77.53727 38.77568 0.00000, -77.53...    153061
# 84   POLYGON Z ((-77.48114 38.75611 0.00000, -77.48...    153062

# %%
#['177702', '153112', '710104', '800602', '095504', '177103', '089505',
 #      '800404', '800504', '153210', '095202', '089304', '800302', '153609',
  #     '177703', '650215', '177402', '153312', '059513', '550020', '177704',
   #    '153110']

shp[(shp['COUNTYFP'] == '153')  & (shp['VTDST'].str.slice(start = 3) == '112')]
# Out:
#   STATEFP COUNTYFP   VTDST                       NAMELSAD VTDI LSAD CHNG_TYPE  \
# 9      51      153  000112  Burke-Nickens Voting District    A   V2      None
#
#   ORIG_NAME ORIG_CODE RELATE           NAME VINTAGE FUNCSTAT JUSTIFY  MTFCC  \
# 9      None      None   None  Burke-Nickens      90        N    None  G5240
#
#                                             geometry unique_id
# 9  POLYGON Z ((-77.70994 38.82376 0.00000, -77.70...    153112

# %%
df_not_in_final = list(set(df_with_absentee_reallocated['unique_id_1']) - set(final['unique_id_1']))

# %%
df_with_absentee_reallocated[df_with_absentee_reallocated['unique_id_1'].isin(df_not_in_final)]
# Out:
#                   Pct          LOCALITY  G18USSDKAI  G18USSRSTE  G18USSLWAT  \
# 37  407 - Biscuit Run  Albemarle County      1083.0       253.0        47.0
# 43      507 - Pantops  Albemarle County      1055.0       454.0        23.0
#
#     G18USSOWRI COUNTYFP vtdst unique_id unique_id_1
# 37         2.0      003   407    003407      003407
# 43         2.0      003   507    003507      003507

# %%
final_notin_df = list(set(final['unique_id_1']) - set(df_with_absentee_reallocated['unique_id_1']))

# %%
final[final['unique_id_1'].isin(final_notin_df)]
# Out:
#      COUNTYFP          LOCALITY   VTDST       PRECINCT  G18USSDKAI  \
# 29        003  Albemarle County  000499    Biscuit Run        1083
# 600       059    Fairfax County  000700  Fairfax Court           0
# 2332      003  Albemarle County  000599        Pantops        1054
#
#       G18USSRSTE  G18USSLWAT  G18USSOWRI  \
# 29           252          47           2
# 600            0           0           0
# 2332         453          23           2
#
#                                                geometry unique_id unique_id_1
# 29    POLYGON Z ((-78.53848 37.98576 0.00000, -78.53...    003499      003499
# 600   POLYGON Z ((-77.31648 38.84615 0.00000, -77.31...    059700      059700
# 2332  POLYGON Z ((-78.45505 38.04404 0.00000, -78.45...    003599      003599

# %%
df_with_absentee_reallocated['unique_id_1'].replace({'003407':'003499', '003507': '003599'}) # == '003407'

#create map as dictionary on own 
#
# Out:
# 1       001101
# 2       001201
# 3       001202
# 4       001301
# 5       001401
#          ...
# 2748    199401
# 2749    199402
# 2750    199403
# 2751    199501
# 2752    199502
# Name: unique_id_1, Length: 2462, dtype: object

# %% [markdown]
# Peter ex:
# cand_name_dict = {"Trump / Pence":"Donald J. Trump","Clinton / Kaine":"Hillary R. Clinton",
#                  "Johnson / Weld":"Gary Johnson","Stein / Baraka":"Jill Stein",
#                  "Write-in":"WriteIn","De La Fuente / Steinberg":"Roque De La Fuente",
#                  "Castle / Bradley":"Darrell L. Castle",'WriteInVotes':'WriteIn','WriteinVotes':'WriteIn'}
#
# #Clean the candidate names
# filtered_frame["CanName"]=filtered_frame["CanName"].map(cand_name_dict).fillna(filtered_frame["CanName"])

# %%
{'003407':'003499', '003507': '003599'}
# Out:
# {'003407': '003499', '003507': '003599'}

# %%
df_with_absentee_reallocated[df_with_absentee_reallocated['unique_id'] == '003407']
# Out:
#                   Pct          LOCALITY  G18USSDKAI  G18USSRSTE  G18USSLWAT  \
# 37  407 - Biscuit Run  Albemarle County      1083.0       253.0        47.0
#
#     G18USSOWRI COUNTYFP vtdst unique_id unique_id_1
# 37         2.0      003   407    003407      003407

# %%
shp.shape
# Out:
# (2462, 17)

# %%
final.shape
# Out:
# (2463, 11)

# %%
df_with_absentee_reallocated.shape
# Out:
# (2462, 10)

# %% [markdown]
# Can do if `unique_id` in `df_double_list`, vtdst = vtdst + CD
#
# See that the non unique values are the same in the final file and the election result file...
#
# Could merge and see how well matches up
#
# could work to see the values that dont match and remedy
#
# Then merge and compare results

# %% [markdown]
# ### Above not working with .replace, come back to
# **In addition to adding** the 22 values that are not unique, will need to add vtdst == 499 and 599 into elections file somehow since there are votes there.

# %% [markdown]
# # Validation

# %% [markdown]
# ### Shapefile comparison:

# %%
len(set(shp.unique_id) - set(final.unique_id)) #better match rate with id not id_1 column

# %%
final.plot()

# %%
shp.plot()

# %% [markdown]
# - Need to run geom almost equals on joined shapefile
# - geom x and y to compare, -- see how many match and dont, of ones that did not match, can see how big or small changes were

# %%
shp_final_merge = pd.merge(shp, final, on = 'unique_id', how = 'inner', suffixes = ['_x', '_y'])

# %%
shp['geometry'].geom_almost_equals(final['geometry'], decimal = 6)

# %%
(set(shp.unique_id) - set(final['unique_id']))

# %%
shp

# %% [markdown]
# ### Election result comparison:

# %%
column_list = ['G18USSDKAI', 'G18USSRSTE', 'G18USSLWAT', 'G18USSOWRI']

# %%
final_df_merge = pd.merge(df_with_absentee_reallocated, final, on = 'unique_id_1', how = 'inner', suffixes = ('_x', '_y'))

# %%
final_df_merge.dropna()
# Out:
#                        Pct       LOCALITY_x  G18USSDKAI_x  G18USSRSTE_x  \
# 0       101 - Chincoteague  Accomack County         557.0         994.0
# 1           201 - Atlantic  Accomack County         182.0         459.0
# 2     202 - Greenbackville  Accomack County         317.0         577.0
# 3         301 - New Church  Accomack County         589.0         477.0
# 4             401 - Bloxom  Accomack County         121.0         277.0
# ...                    ...              ...           ...           ...
# 2455   401 - Harwoods Mill      York County         967.0        1484.0
# 2456            402 - Dare      York County         930.0        1550.0
# 2457         403 - Grafton      York County         566.0         737.0
# 2458            501 - Tabb      York County        1170.0        1477.0
# 2459          502 - Bethel      York County        1397.0        1201.0
#
#       G18USSLWAT_x  G18USSOWRI_x COUNTYFP_x vtdst unique_id_x unique_id_1  \
# 0             17.0           0.0        001   101      001101      001101
# 1             11.0           0.0        001   201      001201      001201
# 2              8.0           1.0        001   202      001202      001202
# 3             11.0           0.0        001   301      001301      001301
# 4              4.0           0.0        001   401      001401      001401
# ...            ...           ...        ...   ...         ...         ...
# 2455          50.0           6.0        199   401      199401      199401
# 2456          38.0           5.0        199   402      199402      199402
# 2457          23.0           1.0        199   403      199403      199403
# 2458          57.0           7.0        199   501      199501      199501
# 2459          57.0           2.0        199   502      199502      199502
#
#      COUNTYFP_y       LOCALITY_y   VTDST        PRECINCT  G18USSDKAI_y  \
# 0           001  Accomack County  000101    Chincoteague           556
# 1           001  Accomack County  000201        Atlantic           182
# 2           001  Accomack County  000202  Greenbackville           316
# 3           001  Accomack County  000301      New Church           588
# 4           001  Accomack County  000401          Bloxom           121
# ...         ...              ...     ...             ...           ...
# 2455        199      York County  000401   HARWOODS MILL           967
# 2456        199      York County  000402            DARE           930
# 2457        199      York County  000403         GRAFTON           566
# 2458        199      York County  000501            TABB          1170
# 2459        199      York County  000502          BETHEL          1397
#
#       G18USSRSTE_y  G18USSLWAT_y  G18USSOWRI_y  \
# 0              994            17             0
# 1              459            11             0
# 2              577             8             1
# 3              477            11             0
# 4              277             4             0
# ...            ...           ...           ...
# 2455          1484            50             6
# 2456          1550            38             5
# 2457           737            23             1
# 2458          1477            58             7
# 2459          1201            57             3
#
#                                                geometry unique_id_y
# 0     POLYGON Z ((-75.42507 37.89957 0.00000, -75.42...      001101
# 1     POLYGON Z ((-75.59978 37.87664 0.00000, -75.59...      001201
# 2     POLYGON Z ((-75.49919 37.93416 0.00000, -75.49...      001202
# 3     POLYGON Z ((-75.64987 37.92702 0.00000, -75.64...      001301
# 4     POLYGON Z ((-75.71556 37.87513 0.00000, -75.71...      001401
# ...                                                 ...         ...
# 2455  POLYGON Z ((-76.47686 37.14917 0.00000, -76.47...      199401
# 2456  POLYGON Z ((-76.46356 37.16058 0.00000, -76.46...      199402
# 2457  POLYGON Z ((-76.48228 37.16839 0.00000, -76.48...      199403
# 2458  MULTIPOLYGON Z (((-76.42953 37.10608 0.00000, ...      199501
# 2459  POLYGON Z ((-76.42954 37.10728 0.00000, -76.42...      199502
#
# [2460 rows x 20 columns]

# %%
#adapted from PDV training
def sum_checker(df, column_list):
    list_max = 0
    for i in column_list:
        left_sum = df[i+'_x'].sum()
        right_sum = df[i+'_y'].sum()
        if (left_sum == right_sum):
            print('column: ', i, ' have the same sums')
        
        else:
            diff = abs(left_sum - right_sum)
            percent = abs(left_sum - right_sum)/left_sum
            print('column: ', i)
            print('RDH sum is ', str(left_sum))
            print('Partner sum is ', str(right_sum))
            print('their (absolute) difference is ', str(diff))
            print('As a percentage of DF1 this is ', str(round(percent*100,5)) + '%')
            if (percent>list_max):
                list_max = percent
            print('')
    print('The max difference (as a percent of the total of on DF column is: ', str(round(list_max,5)))

# %%
sum_checker(final_df_merge, column_list)
# Out:
# column:  G18USSDKAI  have the same sums
# column:  G18USSRSTE
# RDH sum is  1374310.0
# Partner sum is  1374313.0
# their (absolute) difference is  3.0
# As a percentage of DF1 this is  0.00022%
#
# column:  G18USSLWAT
# RDH sum is  61503.0
# Partner sum is  61565.0
# their (absolute) difference is  62.0
# As a percentage of DF1 this is  0.10081%
#
# column:  G18USSOWRI
# RDH sum is  5361.0
# Partner sum is  5509.0
# their (absolute) difference is  148.0
# As a percentage of DF1 this is  2.76068%
#
# The max difference (as a percent of the total of on DF column is:  0.02761

# %% [markdown]
# **Bc 1500 off**, would be helpful to know largest amount it is off by - is it truly off bc of rounding?

# %%
#pulled from sam's pdv training
def validater_row_vect(df, county_column, join_column, column_List):
    matching_rows = 0
    different_rows = 0
    
    county_join_cols = (df[county_column].astype('str') + ' ' + df[join_column].astype('str')).to_numpy()
    
    # it's because before, we were checking that a row was entirely consistent
    # here, we are double checking a lot
    # so, let's just keep one track of the rows that are messed up
    
    wrong_idxs = np.zeros(len(df))
    for i in column_List:
        left_data = df[i + "_x"].to_numpy()
        right_data = df[i + "_y"].to_numpy()
        
        local_idxs = np.where(left_data != right_data)
        wrong_idxs[local_idxs] = 1
        #print("Wrong idxs", wrong_idxs)
        
    # we are close, we get the same result, but are double adding lots of rows
    different_rows += np.sum(wrong_idxs)
    matching_rows += len(df) - different_rows
    
    diff_list = county_join_cols[np.where(wrong_idxs == 1)]
            
    print("There are ", len(df.index)," total rows")
    print(f"{int(different_rows)} of these rows have election result differences")
    print(f"{int(matching_rows)} of these rows are the same")
    print(diff_list)
    print("")

# %%
validater_row_vect(final_df_merge, 'COUNTYFP_x', 'unique_id_1', column_list)
# Out:
# There are  2465  total rows
# 1585 of these rows have election result differences
# 880 of these rows are the same
# ['001 001101' '001 001202' '001 001301' ... 'nan 003499' 'nan 059700'
#  'nan 003599']

# %% [markdown]
# **Discrepencies likely due to rounding errors, esp since totals were better before I added in rounding**

# %%
#From Peter's MO
def validater_row (df, column_List):
    matching_rows = 0
    different_rows = 0
    diff_list=[]
    diff_values = []
    max_diff = 0
    
    for j in range(0,len(df.index)):
        same = True
        for i in column_List:
            left_Data = i + "_x"
            right_Data = i + "_y"
            diff = abs(df.iloc[j][left_Data]-df.iloc[j][right_Data])
            if(diff != 0):
                diff_values.append(abs(diff))
                same = False
                if(np.isnan(diff)):
                    print("NaN value at diff is: ", df.iloc[j]['unique_id_1'])
                if (diff>max_diff):
                    max_diff = diff
                    print("New max diff is: ", str(max_diff))
                    print(df.iloc[j]['unique_id_1'])
        if(same != True):
            different_rows +=1
            diff_list.append(df.iloc[j]['unique_id_1'])
        else:
            matching_rows +=1
    print("There are ", len(df.index)," total rows")
    print(different_rows," of these rows have election result differences")
    print(matching_rows," of these rows are the same")
    print("")
    print("The max difference between any one shared column in a row is: ", max_diff)
    if(len(diff_values)!=0):
        print("The average difference is: ", str(sum(diff_values)/len(diff_values)))
    count_big_diff = len([i for i in diff_values if i > 10])
    print("There are ", str(count_big_diff), "precinct results with a difference greater than 5")
    diff_list.sort()

# %%
col_list = column_list
validater_row(final_df_merge ,col_list)
# Out:
# New max diff is:  1.0
# 001101
# New max diff is:  2.0
# 019101
# New max diff is:  3.0
# 019403
# New max diff is:  4.0
# 019506
# New max diff is:  12.0
# 550001
# New max diff is:  31.0
# 550003
# New max diff is:  124.0
# 059229
# New max diff is:  128.0
# 153112CD 10)
# New max diff is:  157.0
# 153212
# There are  2460  total rows
# 1580  of these rows have election result differences
# 880  of these rows are the same
#
# The max difference between any one shared column in a row is:  157.0
# The average difference is:  6.731955023576351
# There are  479 precinct results with a difference greater than 5

# %%
#Precinct by precinct comparison from pdv training ex
def validater_row(df, county_column, join_column, column_list):
    matching_rows = 0
    different_rows = 0
    diff_list = []
    
    for j in range(0, len(df.index)):
        same = True
        for i in column_list:
            left_data = i + '_x'
            right_data = i + '_y'
            if(df.iloc[j][left_data] - df.iloc[j][right_data] != 0):
                same = False
            if(same != True):
                different_rows += 1
                diff_list.append(str(df.iloc[j][county_column]) + ' ' + str(df.iloc[j][join_column]))
            else:
                matching_rows += 1
        print('There are ', len(df.index), ' total rows')
        print(different_rows," of these rows have election result differences")
        print(matching_rows," of these rows are the same")
        print(diff_list)
        print("")

# %%
validater_row(final_df_merge, 'COUNTYFP_x', 'unique_id_1', column_list)
